# %% [markdown]
# # Data preparation

# %% [markdown]
# ## Library import

# %%
import pandas as pd
import numpy as np

import tensorflow as tf

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Conv1D, Flatten
from tensorflow.keras.optimizers import legacy

from sklearn.preprocessing import MinMaxScaler

import matplotlib
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import matplotlib.font_manager as font_manager

import time

# %% [markdown]
# ## Use Colissimo font for Matplotlib

# %%
font_path = '/Users/anthony/spyder-py3/Font/Monserrat/Montserrat-Regular.otf'

font_manager.fontManager.addfont(font_path)

plt.rcParams['font.family'] = 'Montserrat'

# %% [markdown]
# ## Read dataset

# %%
# Read main data
data = pd.read_excel('/Users/anthony/spyder-py3/ML/traffic_tg1.xlsx', index_col='date')
data.index = pd.to_datetime(data.index)

# Read holiday day data
holidays_data = pd.read_excel('/Users/anthony/spyder-py3/ML/public_holiday.xlsx')
holidays_data['date'] = pd.to_datetime(holidays_data['date'])

# %% [markdown]
# ## Create dummies

# %%
#Create dummies

# Create a dummy for holiday
data['is_holiday'] = data.index.isin(holidays_data['date']).astype(int)

# %% [markdown]
# # Function creation

# %% [markdown]
# ## Custom MAPE/MAE function loss

# %%
def custom_mape(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    mask = tf.math.greater(y_true, 0)
    y_true_masked = tf.boolean_mask(y_true, mask)
    y_pred_masked = tf.boolean_mask(y_pred, mask)

    diff = tf.abs((y_true_masked - y_pred_masked) / y_true_masked)
    return 100. * tf.reduce_mean(diff)

def custom_mae(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    mask = tf.math.greater(y_true, 0)
    y_true_masked = tf.boolean_mask(y_true, mask)
    y_pred_masked = tf.boolean_mask(y_pred, mask)

    diff = tf.abs(y_true_masked - y_pred_masked)
    return 100. * tf.reduce_mean(diff)

# %% [markdown]
# ## CNN model

# %%
# Define a function to create a sequential CNN model
def create_cnn_model(filters, kernel_size, activation, n_steps_in, n_features, optimizer, loss):
    model = Sequential()
    model.add(Conv1D(filters=filters, 
                     kernel_size=kernel_size, 
                     activation=activation, 
                     input_shape=(n_steps_in, n_features)))
    model.add(Conv1D(filters=filters, 
                     kernel_size=7, 
                     activation=activation))
    model.add(Flatten())
    model.add(Dense(1))
    model.compile(optimizer=optimizer, loss=loss, metrics=[custom_mape, custom_mae], run_eagerly=True)
    return model

# %% [markdown]
# ## Scale data

# %%
# Scale data between 0 and 1
def scale_data(data):
    scalers = {}
    data_normalized = data.copy()
    for column in data.columns:
        scaler = MinMaxScaler()
        data_normalized[column] = scaler.fit_transform(data[[column]])
        scalers[column] = scaler
    return data_normalized, scalers

# %% [markdown]
# ## Data transformation

# %%
# Define a function to transfrom data for CNN model
def transform_data_cnn(data_normalized, n_steps_in, start_date, end_date):    
    X, y, dates = [], [], []
    # Filter data based on the start and end dates
    data_filtered = data_normalized[start_date:end_date]
    # Create sequence data of n_steps_in days and n_steps_out days
    for i in range(n_steps_in, len(data_filtered)):
        X.append(data_filtered.iloc[i-n_steps_in:i])
        y.append(data_filtered.iloc[i]['tg1_traffic']) #0 because we just want to predict traffic
        dates.append(data_filtered.index[i])
    X, y, dates = np.array(X), np.array(y), np.array(dates)
    return X, y, dates

# %% [markdown]
# ## Transfer learning

# %%
def transfer_learning(X_train, y_train, n_steps_in, model_params, test_dates, y_test, cnn_model):
    # Initialize empty list to save forecast
    daily_predictions = []
    eight_day_predictions = [0] * len(test_dates)
    
    for i, date in enumerate(test_dates):
        
        # Get traffic of last day to update X_train
        if i == 0:
            new_traffic_point = y_train[-1] # for first forecast, need to take last traffic in train data
        else:
            new_traffic_point = y_test[i-1]
            
        # Create dummies for new datapoint
        current_date = test_dates[i] # forecast's day
        is_holiday = 1 if current_date in holidays_data['date'].values else 0

        # Create new data point with traffic and dummies
        new_data_point = [new_traffic_point, is_holiday]
        new_data_point_array=np.array([new_data_point])

        # Update X_train and y_train
        new_X = np.append(X_train[-1][1:], new_data_point_array, axis=0)
        X_train = np.append(X_train, [new_X], axis=0)
        y_train = np.append(y_train, [y_test[i]])
    
        # Quick update of model for learning transfer
        cnn_model.fit(X_train, y_train, epochs=1, verbose=0)

        # Make 1-day forecast
        
        prediction = cnn_model.predict(X_train[-1].reshape(1, n_steps_in, 2), verbose=0) 
        daily_predictions.append(prediction[0])
        
        # if current date is a Thursday, need to make a 8-day forecast
        if date.weekday() == 3:
            eight_days_data = X_train[-1]
            local_predictions = []
            for k in range(6):
                if i + k < len(test_dates):  # Check that the index does not go beyond the length of test_dates
                    current_date = test_dates[i+k]
                    is_holiday = 1 if current_date in holidays_data['date'].values else 0

                    # Créez un nouveau point de données avec le trafic et les dummies
                    new_prediction_point = [prediction[0][0], is_holiday]
                    new_prediction_point_array = np.array([new_prediction_point])
                    eight_days_data = np.append(eight_days_data[1:], new_prediction_point_array, axis=0)
                    prediction = cnn_model.predict(eight_days_data.reshape(1, n_steps_in, 2), verbose=0)
                    local_predictions.append(prediction[0])
            for j in range(min(5, len(local_predictions)-1)):
                index_to_assign = i+2+j
                if index_to_assign < len(eight_day_predictions):
                    eight_day_predictions[index_to_assign] = local_predictions[1+j][0]




    return daily_predictions, eight_day_predictions

# %% [markdown]
# ## Rescale data

# %%
def rescale_predictions(predictions, scaler):
    predictions_array = np.array(predictions)
    return scaler.inverse_transform(predictions_array.reshape(-1, 1))

# %% [markdown]
# ## Plot test results

# %%
def plot_test_results_from_df(df, title):
    plt.figure(figsize=(15, 7))
    plt.title(title)
    
    # Extraire les données du DataFrame
    test_dates = df.index
    y_test = df['Trafic TG1'].values
    y_test_forecast = df['Prévision globale'].values
    daily_forecast = df['Prévision journalière'].values
    weekly_forecast = df['Prévision hebdomadaire'].values

    # Remplir la zone d'erreur acceptable (+-5%)
    upper_bound = [val * 1.05 for val in y_test]
    lower_bound = [val * 0.95 for val in y_test]
    plt.fill_between(test_dates, upper_bound, lower_bound, color='blue', alpha=0.2)
    
    # Affichage de la prévision lancée d'un coup
    plt.plot(test_dates, y_test_forecast, label='Prévision globale', color='green', marker='o')
    
    # Affichage des prévisions quotidiennes
    plt.plot(test_dates, daily_forecast, label='Prévision journalière', color='red', marker='x')
    
    # Affichage des prévisions hebdomadaires
    plt.plot(test_dates, weekly_forecast, label='Prévision hebdomadaire', color='purple', marker='s')
    
    # Affichage du trafic réel    
    plt.plot(test_dates, y_test, label='Trafic réel', color='blue', linewidth=2)
    

    plt.xlabel('Date')
    plt.ylabel('Trafic')
    plt.legend()
    plt.grid(False)
    plt.show()

# %% [markdown]
# ## Plot train results

# %%
def plot_train_results_from_df(df, title):
    plt.figure(figsize=(15, 7))
    plt.title(title)
    
    # Extraire les données du DataFrame
    train_dates = df.index
    y_train = df['Trafic TG1'].values
    y_train_forecast = df['Prévision globale'].values

    # Remplir la zone d'erreur acceptable (+-5%)
    upper_bound = [val * 1.05 for val in y_train]
    lower_bound = [val * 0.95 for val in y_train]
    plt.fill_between(train_dates, upper_bound, lower_bound, color='blue', alpha=0.2)
    

    
    
    # Affichage du trafic réel    
    plt.plot(train_dates, y_train, label='Trafic réel', color='blue')
    # Affichage de la prévision lancée d'un coup
    plt.plot(train_dates, y_train_forecast, label='Prévision globale', color='green', linewidth = 2)
    

    plt.xlabel('Date')
    plt.ylabel('Trafic')
    plt.legend()
    plt.grid(False)
    plt.show()

# %% [markdown]
# ## Calculate MAPE

# %%
def calculate_mean_max_mape(actual, forecast):
    # Éviter la division par zéro et les erreurs NaN
    mask = actual != 0
    mape_values = np.abs((actual[mask] - forecast[mask]) / actual[mask]) * 100
    return np.mean(mape_values), np.max(mape_values)

def compute_mape_for_columns(df, actual_col, forecast_cols):
    mape_stats = {}
    for col in forecast_cols:
        valid_forecast_mask = ~df[col].isna()
        avg_mape, max_mape = calculate_mean_max_mape(df[actual_col][valid_forecast_mask], df[col][valid_forecast_mask])
        mape_stats[col] = {"avg_mape": avg_mape, "max_mape": max_mape}
    return mape_stats

# %% [markdown]
# # Data preparation

# %% [markdown]
# Take out saturday and sunday of data, normalized the data before creating training and test dataset.
# <br>
# n_steps_in is the number of week $\times$ number of day in a week (here 5)

# %%
# Exclusion des jours de la semaine (samedi et dimanche)
data = data[(data.index.dayofweek != 5) & (data.index.dayofweek != 6)]

data_normalized, scaler = scale_data(data)

n_steps_in =260

X_train, y_train, train_dates = transform_data_cnn(data_normalized, 
                                                   n_steps_in,  
                                                   '2017-01-01', 
                                                   '2022-12-31')

X_test, y_test, test_dates = transform_data_cnn(data_normalized, 
                                                n_steps_in, 
                                                '2022-01-01', 
                                                '2023-03-15')

# %% [markdown]
# # Model creation

# %% [markdown]
# ## Model parameters

# %%
# Paramètres du modèle
model_params = {
    "filters": 64,
    "kernel_size": 7,
    "activation": "relu",
    "n_steps_in": n_steps_in,
    "n_features": 2,
    "optimizer": 'adam',
    "loss": custom_mape
}

# %% [markdown]
# ## Model creation

# %%
cnn_model = create_cnn_model(**model_params)
history = cnn_model.fit(X_train, y_train, epochs=40)
# Historique des pertes
train_loss = history.history['loss']

epochs = range(1, len(train_loss) + 1)
plt.plot(epochs, train_loss, label='Training Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# Epoch 1/40
# 41/41 [==============================] - 2s 37ms/step - loss: 46.6951 - custom_mape: 46.6315 - custom_mae: 14.4436
# Epoch 2/40
# 41/41 [==============================] - 1s 36ms/step - loss: 30.3636 - custom_mape: 30.3181 - custom_mae: 9.9338
# Epoch 3/40
# 41/41 [==============================] - 1s 35ms/step - loss: 23.1728 - custom_mape: 23.1835 - custom_mae: 7.9250
# Epoch 4/40
# 41/41 [==============================] - 1s 36ms/step - loss: 26.0606 - custom_mape: 26.0125 - custom_mae: 8.9446
# Epoch 5/40
# 41/41 [==============================] - 1s 35ms/step - loss: 22.5176 - custom_mape: 22.4979 - custom_mae: 8.1273
# Epoch 6/40
# 41/41 [==============================] - 1s 33ms/step - loss: 24.7409 - custom_mape: 24.7931 - custom_mae: 8.1748
# Epoch 7/40
# 41/41 [==============================] - 1s 32ms/step - loss: 23.7174 - custom_mape: 23.6947 - custom_mae: 7.7884
# Epoch 8/40
# 41/41 [==============================] - 1s 34ms/step - loss: 19.7615 - custom_mape: 19.7246 - custom_mae: 6.9668
# Epoch 9/40
# 41/41 [==============================] - 1s 36ms/step - loss: 20.0880 - custom_mape: 20.0802 - custom_mae: 6.7882
# Epoch 10/40
# 41/41 [==============================] - 1s 33ms/step - loss: 18.9064 - custom_mape: 18.9794 - custom_mae: 7.2615
# Epoch 11/40
# 41/41 [==============================] - 1s 32ms/step - loss: 20.1798 - custom_mape: 20.1531 - custom_mae: 6.7467
# Epoch 12/40
# 41/41 [==============================] - 1s 32ms/step - loss: 17.6177 - custom_mape: 17.6440 - custom_mae: 6.7134
# Epoch 13/40
# 41/41 [==============================] - 1s 32ms/step - loss: 17.3536 - custom_mape: 17.3215 - custom_mae: 6.1978
# Epoch 14/40
# 41/41 [==============================] - 1s 32ms/step - loss: 17.5048 - custom_mape: 17.4842 - custom_mae: 6.0189
# Epoch 15/40
# 41/41 [==============================] - 1s 32ms/step - loss: 14.6298 - custom_mape: 14.6239 - custom_mae: 5.6822
# Epoch 16/40
# 41/41 [==============================] - 1s 35ms/step - loss: 15.0357 - custom_mape: 15.1159 - custom_mae: 5.5273
# Epoch 17/40
# 41/41 [==============================] - 1s 32ms/step - loss: 17.0987 - custom_mape: 17.0733 - custom_mae: 6.0212
# Epoch 18/40
# 41/41 [==============================] - 1s 33ms/step - loss: 16.1441 - custom_mape: 16.1557 - custom_mae: 5.8761
# Epoch 19/40
# 41/41 [==============================] - 1s 33ms/step - loss: 16.4729 - custom_mape: 16.4573 - custom_mae: 5.8243
# Epoch 20/40
# 41/41 [==============================] - 2s 44ms/step - loss: 13.6692 - custom_mape: 13.6543 - custom_mae: 5.4972
# Epoch 21/40
# 41/41 [==============================] - 2s 38ms/step - loss: 14.9747 - custom_mape: 14.9450 - custom_mae: 5.1526
# Epoch 22/40
# 41/41 [==============================] - 1s 33ms/step - loss: 12.8035 - custom_mape: 12.7959 - custom_mae: 4.9324
# Epoch 23/40
# 41/41 [==============================] - 1s 35ms/step - loss: 12.8462 - custom_mape: 12.8435 - custom_mae: 4.6266
# Epoch 24/40
# 41/41 [==============================] - 2s 42ms/step - loss: 11.9717 - custom_mape: 11.9458 - custom_mae: 4.8580
# Epoch 25/40
# 41/41 [==============================] - 2s 39ms/step - loss: 12.4817 - custom_mape: 12.4501 - custom_mae: 4.2937
# Epoch 26/40
# 41/41 [==============================] - 2s 39ms/step - loss: 11.8065 - custom_mape: 11.7901 - custom_mae: 4.3275
# Epoch 27/40
# 41/41 [==============================] - 1s 32ms/step - loss: 12.7290 - custom_mape: 12.7316 - custom_mae: 4.7154
# Epoch 28/40
# 41/41 [==============================] - 1s 32ms/step - loss: 11.3260 - custom_mape: 11.3034 - custom_mae: 4.2930
# Epoch 29/40
# 41/41 [==============================] - 1s 32ms/step - loss: 11.0221 - custom_mape: 11.0135 - custom_mae: 4.0218
# Epoch 30/40
# 41/41 [==============================] - 1s 31ms/step - loss: 12.1798 - custom_mape: 12.1625 - custom_mae: 4.1603
# Epoch 31/40
# 41/41 [==============================] - 1s 36ms/step - loss: 9.4648 - custom_mape: 9.4711 - custom_mae: 3.7873
# Epoch 32/40
# 41/41 [==============================] - 1s 32ms/step - loss: 11.7011 - custom_mape: 11.6619 - custom_mae: 4.0821
# Epoch 33/40
# 41/41 [==============================] - 1s 32ms/step - loss: 9.2670 - custom_mape: 9.2780 - custom_mae: 3.7146
# Epoch 34/40
# 41/41 [==============================] - 2s 40ms/step - loss: 9.5090 - custom_mape: 9.8556 - custom_mae: 3.3992
# Epoch 35/40
# 41/41 [==============================] - 1s 32ms/step - loss: 15.5371 - custom_mape: 15.4970 - custom_mae: 5.1482
# Epoch 36/40
# 41/41 [==============================] - 1s 35ms/step - loss: 8.0708 - custom_mape: 8.0701 - custom_mae: 3.3134
# Epoch 37/40
# 41/41 [==============================] - 2s 40ms/step - loss: 8.9076 - custom_mape: 8.9095 - custom_mae: 3.1345
# Epoch 38/40
# 41/41 [==============================] - 2s 41ms/step - loss: 7.6886 - custom_mape: 7.7226 - custom_mae: 3.0970
# Epoch 39/40
# 41/41 [==============================] - 2s 44ms/step - loss: 9.7750 - custom_mape: 9.7760 - custom_mae: 3.3639
# Epoch 40/40
# 41/41 [==============================] - 3s 68ms/step - loss: 7.7135 - custom_mape: 7.7042 - custom_mae: 3.0352

# %% [markdown]
# ## Global forecast

# %%
y_train_forecast = cnn_model.predict(X_train)
y_test_forecast = cnn_model.predict(X_test)
# Out:
# 41/41 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 231ms/step

# %% [markdown]
# ## Daily and Weekly Forecast

# %%
start_time = time.time()
daily_forecast, weekly_forecast = transfer_learning(X_train,y_train,n_steps_in,model_params,test_dates,y_test,cnn_model)
print("--- Transfert d'apprentissage: %s seconds ---" % (time.time() - start_time))
# Out:
# --- Transfert d'apprentissage: 98.13312888145447 seconds ---

# %% [markdown]
# # Data analysis

# %% [markdown]
# ## Rescale data

# %%
y_train_forecast_rescaled = rescale_predictions(y_train_forecast, scaler['tg1_traffic'])
y_train_rescaled = rescale_predictions(y_train, scaler['tg1_traffic'])


y_test_forecast_rescaled = rescale_predictions(y_test_forecast, scaler['tg1_traffic'])
y_test_rescaled = rescale_predictions(y_test, scaler['tg1_traffic'])



daily_forecast_rescaled = rescale_predictions(daily_forecast, scaler['tg1_traffic'])
weekly_forecast_rescaled = rescale_predictions(weekly_forecast, scaler['tg1_traffic'])

# %% [markdown]
# ## Concatenate forecast in dataframe

# %%
data_train_forecast = pd.DataFrame({
    'Trafic TG1' : y_train_rescaled.flatten().tolist() ,
    'Prévision globale' : y_train_forecast_rescaled.flatten().tolist()
                            }, index = train_dates.tolist())

data_test_forecast = pd.DataFrame({
    'Trafic TG1' : y_test_rescaled.flatten().tolist() ,
    'Prévision globale' : y_test_forecast_rescaled.flatten().tolist(),
    'Prévision hebdomadaire' : weekly_forecast_rescaled.flatten().tolist(),
    'Prévision journalière' : daily_forecast_rescaled.flatten().tolist()  
                            }, index = test_dates.tolist())

# %% [markdown]
# ## Plot results

# %%
plot_test_results_from_df(data_test_forecast, 'Transfert d’apprentissage')

# %%
plot_train_results_from_df(data_train_forecast, "Résultats d'entraînement")

# %% [markdown]
# ## Metrics

# %%
# Utilisation de la fonction:
forecast_columns = ['Prévision globale', 'Prévision journalière', 'Prévision hebdomadaire']
mapes = compute_mape_for_columns(data_test_forecast, 'Trafic TG1', forecast_columns)

for col, mape_stats in mapes.items():
    avg_mape = mape_stats['avg_mape']
    max_mape = mape_stats['max_mape']
    print(f"MAPE moyen {col} : {avg_mape:.2f}%")
    print(f"MAPE max {col} : {max_mape:.2f}%")
    print("-" * 30)  # Juste pour séparer visuellement les différentes prévisions
# Out:
# MAPE moyen Prévision globale : 12.51%
# MAPE max Prévision globale : 43.81%
# ------------------------------
# MAPE moyen Prévision journalière : 13.07%
# MAPE max Prévision journalière : 60.85%
# ------------------------------
# MAPE moyen Prévision hebdomadaire : 22.54%
# MAPE max Prévision hebdomadaire : 100.00%
# ------------------------------

# %%
# Utilisation de la fonction:
forecast_columns = ['Prévision globale']
mapes = compute_mape_for_columns(data_train_forecast, 'Trafic TG1', forecast_columns)

for col, mape_stats in mapes.items():
    avg_mape = mape_stats['avg_mape']
    max_mape = mape_stats['max_mape']
    print(f"MAPE moyen {col} : {avg_mape:.2f}%")
    print(f"MAPE max {col} : {max_mape:.2f}%")
# Out:
# MAPE moyen Prévision globale : 7.87%
# MAPE max Prévision globale : 1460.06%

# %% [markdown]
# # Tuning

# %%
def run(model_params):
    cnn_model = create_cnn_model(**model_params)
    history = cnn_model.fit(X_train, y_train, epochs=100)
    # Historique des pertes
    train_loss = history.history['loss']

    epochs = range(1, len(train_loss) + 1)

    plt.plot(epochs, train_loss, label='Training Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()
    
    y_train_forecast = cnn_model.predict(X_train)
    y_test_forecast = cnn_model.predict(X_test)

    daily_forecast, weekly_forecast = transfer_learning(X_train,y_train,n_steps_in,model_params,test_dates,y_test,cnn_model)
    
    y_train_forecast_rescaled = rescale_predictions(y_train_forecast, scaler['tg1_traffic'])
    y_train_rescaled = rescale_predictions(y_train, scaler['tg1_traffic'])


    y_test_forecast_rescaled = rescale_predictions(y_test_forecast, scaler['tg1_traffic'])
    y_test_rescaled = rescale_predictions(y_test, scaler['tg1_traffic'])



    daily_forecast_rescaled = rescale_predictions(daily_forecast, scaler['tg1_traffic'])
    weekly_forecast_rescaled = rescale_predictions(weekly_forecast, scaler['tg1_traffic'])
    
    data_train_forecast = pd.DataFrame({
    'Trafic TG1' : y_train_rescaled.flatten().tolist() ,
    'Prévision globale' : y_train_forecast_rescaled.flatten().tolist()
                            }, index = train_dates.tolist())

    data_test_forecast = pd.DataFrame({
    'Trafic TG1' : y_test_rescaled.flatten().tolist() ,
    'Prévision globale' : y_test_forecast_rescaled.flatten().tolist(),
    'Prévision hebdomadaire' : weekly_forecast_rescaled.flatten().tolist(),
    'Prévision journalière' : daily_forecast_rescaled.flatten().tolist()  
                            }, index = test_dates.tolist())
    
    plot_test_results_from_df(data_test_forecast, 'Transfert d’apprentissage')
    plot_train_results_from_df(data_train_forecast, "Résultats d'entraînement")
    
    # Utilisation de la fonction:
    forecast_columns = ['Prévision globale', 'Prévision journalière', 'Prévision hebdomadaire']
    mapes = compute_mape_for_columns(data_test_forecast, 'Trafic TG1', forecast_columns)

    for col, mape in mapes.items():
        print(f"MAPE {col} : {mape:.2f}%")
        
    # Utilisation de la fonction:
    forecast_columns = ['Prévision globale']
    mapes = compute_mape_for_columns(data_train_forecast, 'Trafic TG1', forecast_columns)

    for col, mape in mapes.items():
        print(f"MAPE {col} : {mape:.2f}%")

# %%
# Paramètres du modèle
model_params = {
    "filters": 32,
    "kernel_size": 7,
    "activation": "relu",
    "n_steps_in": n_steps_in,
    "n_features": 2,
    "optimizer": 'adam',
    "loss": custom_mape
}

run(model_params)
# Out:
# Epoch 1/100
# 33/33 [==============================] - 1s 29ms/step - loss: 39.1476 - custom_mape: 38.9628 - custom_mae: 11.0048
# Epoch 2/100
# 33/33 [==============================] - 1s 29ms/step - loss: 27.3146 - custom_mape: 27.2411 - custom_mae: 8.7005
# Epoch 3/100
# 33/33 [==============================] - 1s 29ms/step - loss: 26.9793 - custom_mape: 26.8619 - custom_mae: 8.8417
# Epoch 4/100
# 33/33 [==============================] - 1s 29ms/step - loss: 24.9669 - custom_mape: 24.9080 - custom_mae: 8.5090
# Epoch 5/100
# 33/33 [==============================] - 1s 29ms/step - loss: 19.7843 - custom_mape: 19.7667 - custom_mae: 7.1457
# Epoch 6/100
# 33/33 [==============================] - 1s 29ms/step - loss: 24.9582 - custom_mape: 24.9202 - custom_mae: 8.2738
# Epoch 7/100
# 33/33 [==============================] - 1s 30ms/step - loss: 18.1432 - custom_mape: 18.1033 - custom_mae: 6.8601
# Epoch 8/100
# 33/33 [==============================] - 1s 29ms/step - loss: 19.9477 - custom_mape: 19.9553 - custom_mae: 6.5345
# Epoch 9/100
# 33/33 [==============================] - 1s 29ms/step - loss: 17.8008 - custom_mape: 17.7692 - custom_mae: 6.3962
# Epoch 10/100
# 33/33 [==============================] - 1s 29ms/step - loss: 19.3801 - custom_mape: 19.5355 - custom_mae: 6.3041
# Epoch 11/100
# 33/33 [==============================] - 1s 29ms/step - loss: 15.8476 - custom_mape: 15.8564 - custom_mae: 5.7226
# Epoch 12/100
# 33/33 [==============================] - 1s 29ms/step - loss: 14.9623 - custom_mape: 15.1687 - custom_mae: 5.5405
# Epoch 13/100
# 33/33 [==============================] - 1s 29ms/step - loss: 15.0152 - custom_mape: 15.0072 - custom_mae: 5.6209
# Epoch 14/100
# 33/33 [==============================] - 1s 29ms/step - loss: 15.4818 - custom_mape: 15.4504 - custom_mae: 5.6810
# Epoch 15/100
# 33/33 [==============================] - 1s 29ms/step - loss: 15.0468 - custom_mape: 15.0202 - custom_mae: 5.0894
# Epoch 16/100
# 33/33 [==============================] - 1s 29ms/step - loss: 12.8811 - custom_mape: 12.8350 - custom_mae: 4.7693
# Epoch 17/100
# 33/33 [==============================] - 1s 29ms/step - loss: 14.0605 - custom_mape: 14.0242 - custom_mae: 4.5793
# Epoch 18/100
# 33/33 [==============================] - 1s 29ms/step - loss: 11.5163 - custom_mape: 11.5034 - custom_mae: 4.4383
# Epoch 19/100
# 33/33 [==============================] - 1s 29ms/step - loss: 14.7773 - custom_mape: 14.7416 - custom_mae: 4.7443
# Epoch 20/100
# 33/33 [==============================] - 1s 29ms/step - loss: 11.9420 - custom_mape: 11.9163 - custom_mae: 4.5581
# Epoch 21/100
# 33/33 [==============================] - 1s 29ms/step - loss: 12.6151 - custom_mape: 12.5774 - custom_mae: 3.9892
# Epoch 22/100
# 33/33 [==============================] - 1s 30ms/step - loss: 11.7343 - custom_mape: 12.3020 - custom_mae: 4.1932
# Epoch 23/100
# 33/33 [==============================] - 1s 30ms/step - loss: 15.8432 - custom_mape: 15.7700 - custom_mae: 5.4564
# Epoch 24/100
# 33/33 [==============================] - 1s 29ms/step - loss: 10.7869 - custom_mape: 10.7955 - custom_mae: 4.4722
# Epoch 25/100
# 33/33 [==============================] - 1s 29ms/step - loss: 15.3095 - custom_mape: 15.2243 - custom_mae: 4.6786
# Epoch 26/100
# 33/33 [==============================] - 1s 31ms/step - loss: 11.0118 - custom_mape: 11.0230 - custom_mae: 4.0958
# Epoch 27/100
# 33/33 [==============================] - 1s 29ms/step - loss: 12.9496 - custom_mape: 12.9281 - custom_mae: 4.4168
# Epoch 28/100
# 33/33 [==============================] - 1s 29ms/step - loss: 11.3182 - custom_mape: 11.3123 - custom_mae: 4.1944
# Epoch 29/100
# 33/33 [==============================] - 1s 29ms/step - loss: 10.7358 - custom_mape: 10.7492 - custom_mae: 3.6125
# Epoch 30/100
# 33/33 [==============================] - 1s 29ms/step - loss: 9.2356 - custom_mape: 9.2007 - custom_mae: 3.3595
# Epoch 31/100
# 33/33 [==============================] - 1s 30ms/step - loss: 11.1523 - custom_mape: 11.1332 - custom_mae: 3.9617
# Epoch 32/100
# 33/33 [==============================] - 1s 29ms/step - loss: 9.4252 - custom_mape: 9.4136 - custom_mae: 3.5083
# Epoch 33/100
# 33/33 [==============================] - 1s 29ms/step - loss: 10.7437 - custom_mape: 10.7408 - custom_mae: 3.4300
# Epoch 34/100
# 33/33 [==============================] - 1s 29ms/step - loss: 9.2146 - custom_mape: 9.1863 - custom_mae: 3.3870
# Epoch 35/100
# 33/33 [==============================] - 1s 29ms/step - loss: 8.4600 - custom_mape: 8.4253 - custom_mae: 2.8466
# Epoch 36/100
# 33/33 [==============================] - 1s 29ms/step - loss: 8.8684 - custom_mape: 8.8578 - custom_mae: 3.0545
# Epoch 37/100
# 33/33 [==============================] - 1s 29ms/step - loss: 8.2940 - custom_mape: 8.2649 - custom_mae: 2.8459
# Epoch 38/100
# 33/33 [==============================] - 1s 29ms/step - loss: 7.8130 - custom_mape: 7.7999 - custom_mae: 2.5117
# Epoch 39/100
# 33/33 [==============================] - 1s 30ms/step - loss: 6.4225 - custom_mape: 6.4200 - custom_mae: 2.5146
# Epoch 40/100
# 33/33 [==============================] - 1s 29ms/step - loss: 7.8571 - custom_mape: 7.8416 - custom_mae: 2.5348
# Epoch 41/100
# 33/33 [==============================] - 1s 30ms/step - loss: 7.6981 - custom_mape: 7.6603 - custom_mae: 2.5357
# Epoch 42/100
# 33/33 [==============================] - 1s 30ms/step - loss: 7.5932 - custom_mape: 7.5583 - custom_mae: 2.3919
# Epoch 43/100
# 33/33 [==============================] - 1s 29ms/step - loss: 6.8308 - custom_mape: 6.8308 - custom_mae: 2.4217
# Epoch 44/100
# 33/33 [==============================] - 1s 30ms/step - loss: 8.6780 - custom_mape: 8.6491 - custom_mae: 2.7552
# Epoch 45/100
# 33/33 [==============================] - 1s 30ms/step - loss: 6.2952 - custom_mape: 6.2826 - custom_mae: 2.3082
# Epoch 46/100
# 33/33 [==============================] - 1s 29ms/step - loss: 7.2678 - custom_mape: 8.1395 - custom_mae: 2.2174
# Epoch 47/100
# 33/33 [==============================] - 1s 29ms/step - loss: 7.8569 - custom_mape: 7.8364 - custom_mae: 2.3806
# Epoch 48/100
# 33/33 [==============================] - 1s 30ms/step - loss: 8.3781 - custom_mape: 8.3718 - custom_mae: 2.9678
# Epoch 49/100
# 33/33 [==============================] - 1s 29ms/step - loss: 8.0131 - custom_mape: 7.9826 - custom_mae: 2.4416
# Epoch 50/100
# 33/33 [==============================] - 1s 30ms/step - loss: 6.8265 - custom_mape: 6.8098 - custom_mae: 2.4165
# Epoch 51/100
# 33/33 [==============================] - 1s 29ms/step - loss: 7.1254 - custom_mape: 7.1207 - custom_mae: 2.0631
# Epoch 52/100
# 33/33 [==============================] - 1s 29ms/step - loss: 6.4321 - custom_mape: 6.4249 - custom_mae: 2.1552
# Epoch 53/100
# 33/33 [==============================] - 1s 31ms/step - loss: 6.8823 - custom_mape: 6.8607 - custom_mae: 2.2257
# Epoch 54/100
# 33/33 [==============================] - 1s 29ms/step - loss: 6.3660 - custom_mape: 6.3501 - custom_mae: 2.0644
# Epoch 55/100
# 33/33 [==============================] - 1s 30ms/step - loss: 5.9368 - custom_mape: 5.9167 - custom_mae: 1.8681
# Epoch 56/100
# 33/33 [==============================] - 1s 30ms/step - loss: 6.2218 - custom_mape: 6.1842 - custom_mae: 1.9540
# Epoch 57/100
# 33/33 [==============================] - 1s 30ms/step - loss: 5.6253 - custom_mape: 5.6322 - custom_mae: 1.7472
# Epoch 58/100
# 33/33 [==============================] - 1s 30ms/step - loss: 7.4966 - custom_mape: 7.4586 - custom_mae: 2.5436
# Epoch 59/100
# 33/33 [==============================] - 1s 30ms/step - loss: 6.4587 - custom_mape: 6.4267 - custom_mae: 2.0886
# Epoch 60/100
# 33/33 [==============================] - 1s 29ms/step - loss: 5.5148 - custom_mape: 5.5255 - custom_mae: 1.6480
# Epoch 61/100
# 33/33 [==============================] - 1s 29ms/step - loss: 5.4047 - custom_mape: 5.4244 - custom_mae: 1.6269
# Epoch 62/100
# 33/33 [==============================] - 1s 29ms/step - loss: 6.3944 - custom_mape: 6.3572 - custom_mae: 1.9375
# Epoch 63/100
# 33/33 [==============================] - 1s 30ms/step - loss: 4.6592 - custom_mape: 4.6589 - custom_mae: 1.5941
# Epoch 64/100
# 33/33 [==============================] - 1s 30ms/step - loss: 5.8901 - custom_mape: 5.8680 - custom_mae: 1.6895
# Epoch 65/100
# 33/33 [==============================] - 1s 29ms/step - loss: 5.2304 - custom_mape: 5.2375 - custom_mae: 1.7419
# Epoch 66/100
# 33/33 [==============================] - 1s 29ms/step - loss: 6.0720 - custom_mape: 6.0353 - custom_mae: 1.6525
# Epoch 67/100
# 33/33 [==============================] - 1s 28ms/step - loss: 4.0491 - custom_mape: 4.0513 - custom_mae: 1.4626
# Epoch 68/100
# 33/33 [==============================] - 1s 28ms/step - loss: 6.3140 - custom_mape: 6.2996 - custom_mae: 1.6288
# Epoch 69/100
# 33/33 [==============================] - 1s 29ms/step - loss: 4.7411 - custom_mape: 4.7351 - custom_mae: 1.7027
# Epoch 70/100
# 33/33 [==============================] - 1s 29ms/step - loss: 6.7885 - custom_mape: 6.7710 - custom_mae: 1.9390
# Epoch 71/100
# 33/33 [==============================] - 1s 29ms/step - loss: 4.8233 - custom_mape: 4.8505 - custom_mae: 1.6776
# Epoch 72/100
# 33/33 [==============================] - 1s 29ms/step - loss: 7.1269 - custom_mape: 7.0867 - custom_mae: 1.9528
# Epoch 73/100
# 33/33 [==============================] - 1s 29ms/step - loss: 4.2683 - custom_mape: 4.2604 - custom_mae: 1.4869
# Epoch 74/100
# 33/33 [==============================] - 1s 30ms/step - loss: 5.1661 - custom_mape: 5.1449 - custom_mae: 1.4038
# Epoch 75/100
# 33/33 [==============================] - 1s 29ms/step - loss: 3.4995 - custom_mape: 3.4936 - custom_mae: 1.1827
# Epoch 76/100
# 33/33 [==============================] - 1s 29ms/step - loss: 6.3754 - custom_mape: 6.3515 - custom_mae: 1.7594
# Epoch 77/100
# 33/33 [==============================] - 1s 29ms/step - loss: 4.6390 - custom_mape: 4.6231 - custom_mae: 1.4751
# Epoch 78/100
# 33/33 [==============================] - 1s 29ms/step - loss: 5.0755 - custom_mape: 5.0429 - custom_mae: 1.5415
# Epoch 79/100
# 33/33 [==============================] - 1s 29ms/step - loss: 4.0001 - custom_mape: 3.9919 - custom_mae: 1.2456
# Epoch 80/100
# 33/33 [==============================] - 1s 29ms/step - loss: 4.6618 - custom_mape: 4.6507 - custom_mae: 1.3336
# Epoch 81/100
# 33/33 [==============================] - 1s 29ms/step - loss: 5.0563 - custom_mape: 5.0322 - custom_mae: 1.4611
# Epoch 82/100
# 33/33 [==============================] - 1s 29ms/step - loss: 3.9956 - custom_mape: 3.9950 - custom_mae: 1.3357
# Epoch 83/100
# 33/33 [==============================] - 1s 29ms/step - loss: 4.9573 - custom_mape: 4.9604 - custom_mae: 1.4821
# Epoch 84/100
# 33/33 [==============================] - 1s 35ms/step - loss: 4.8238 - custom_mape: 4.8259 - custom_mae: 1.4111
# Epoch 85/100
# 33/33 [==============================] - 1s 29ms/step - loss: 5.1187 - custom_mape: 5.0997 - custom_mae: 1.6261
# Epoch 86/100
# 33/33 [==============================] - 1s 29ms/step - loss: 3.8268 - custom_mape: 3.8214 - custom_mae: 1.3158
# Epoch 87/100
# 33/33 [==============================] - 1s 29ms/step - loss: 4.3640 - custom_mape: 4.3441 - custom_mae: 1.2090
# Epoch 88/100
# 33/33 [==============================] - 1s 29ms/step - loss: 3.7344 - custom_mape: 3.7243 - custom_mae: 1.1389
# Epoch 89/100
# 33/33 [==============================] - 1s 29ms/step - loss: 4.4237 - custom_mape: 4.4215 - custom_mae: 1.2170
# Epoch 90/100
# 33/33 [==============================] - 1s 29ms/step - loss: 3.9878 - custom_mape: 3.9703 - custom_mae: 1.2880
# Epoch 91/100
# 33/33 [==============================] - 1s 29ms/step - loss: 4.2573 - custom_mape: 4.2415 - custom_mae: 1.1629
# Epoch 92/100
# 33/33 [==============================] - 1s 29ms/step - loss: 4.1190 - custom_mape: 4.1050 - custom_mae: 1.4028
# Epoch 93/100
# 33/33 [==============================] - 1s 29ms/step - loss: 4.5239 - custom_mape: 4.5056 - custom_mae: 1.2462
# Epoch 94/100
# 33/33 [==============================] - 1s 29ms/step - loss: 3.3305 - custom_mape: 3.3269 - custom_mae: 1.1243
# Epoch 95/100
# 33/33 [==============================] - 1s 29ms/step - loss: 4.6594 - custom_mape: 4.6368 - custom_mae: 1.2426
# Epoch 96/100
# 33/33 [==============================] - 1s 29ms/step - loss: 3.3717 - custom_mape: 3.3669 - custom_mae: 1.1518
# Epoch 97/100
# 33/33 [==============================] - 1s 30ms/step - loss: 4.9982 - custom_mape: 5.0012 - custom_mae: 1.3862
# Epoch 98/100
# 33/33 [==============================] - 1s 29ms/step - loss: 3.6197 - custom_mape: 3.6015 - custom_mae: 1.2750
# Epoch 99/100
# 33/33 [==============================] - 1s 29ms/step - loss: 4.4569 - custom_mape: 4.4391 - custom_mae: 1.2342
# Epoch 100/100
# 33/33 [==============================] - 1s 29ms/step - loss: 3.2534 - custom_mape: 3.2440 - custom_mae: 1.1378
# 33/33 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 24ms/step
# MAPE Prévision globale : 12.41%
# MAPE Prévision journalière : 12.10%
# MAPE Prévision hebdomadaire : 58.94%
# MAPE Prévision globale : 4.00%
