# %% [markdown]
# # Data preparation

# %% [markdown]
# ## Library import

# %%
import pandas as pd
import numpy as np

import tensorflow as tf

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Conv1D, Flatten
from tensorflow.keras.optimizers import legacy
from tensorflow.keras.callbacks import EarlyStopping

from keras_tuner import HyperModel
from keras_tuner import Objective
from keras_tuner.tuners import BayesianOptimization

from keras.regularizers import l1, l2, l1_l2

from sklearn.preprocessing import MinMaxScaler

import matplotlib
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import matplotlib.font_manager as font_manager

import time

import shutil

# %% [markdown]
# ## Use Colissimo font for Matplotlib

# %%
font_path = '/Users/anthony/spyder-py3/Font/Monserrat/Montserrat-Regular.otf'

font_manager.fontManager.addfont(font_path)

plt.rcParams['font.family'] = 'Montserrat'

# %% [markdown]
# ## Read dataset

# %%
# Read main data
data = pd.read_excel('data/traffic_tg1.xlsx', index_col='date')
data.index = pd.to_datetime(data.index)

# Read holiday day data
holidays_data = pd.read_excel('data/public_holiday.xlsx')
holidays_data['date'] = pd.to_datetime(holidays_data['date'])

# %% [markdown]
# ## Create dummies

# %%
#Create dummies

# Create a dummy for holiday
data['is_holiday'] = data.index.isin(holidays_data['date']).astype(int)

# %% [markdown]
# # Function creation

# %% [markdown]
# ## Custom MAPE/MAE function loss

# %%
def custom_mape(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    mask = tf.math.greater(y_true, 0)
    y_true_masked = tf.boolean_mask(y_true, mask)
    y_pred_masked = tf.boolean_mask(y_pred, mask)

    diff = tf.abs((y_true_masked - y_pred_masked) / y_true_masked)
    return 100. * tf.reduce_mean(diff)

def custom_mae(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    mask = tf.math.greater(y_true, 0)
    y_true_masked = tf.boolean_mask(y_true, mask)
    y_pred_masked = tf.boolean_mask(y_pred, mask)

    diff = tf.abs(y_true_masked - y_pred_masked)
    return 100. * tf.reduce_mean(diff)

# %% [markdown]
# ## CNN model

# %%
def create_cnn_model(filters, kernel_size, activation, n_steps_in, n_features, optimizer, loss, 
                     reg_type=None, l1_value=0.0, l2_value=0.0):
    if reg_type == 'l1':
        kernel_regularizer = l1(l1_value)
    elif reg_type == 'l2':
        kernel_regularizer = l2(l2_value)
    elif reg_type == 'l1_l2':
        kernel_regularizer = l1_l2(l1=l1_value, l2=l2_value)
    else:
        kernel_regularizer = None
    
    model = Sequential()
    model.add(Conv1D(filters=filters, 
                     kernel_size=kernel_size, 
                     activation=activation, 
                     kernel_regularizer=kernel_regularizer, 
                     input_shape=(n_steps_in, n_features)))
    model.add(Conv1D(filters=filters, 
                     kernel_size=7, 
                     activation=activation, 
                     kernel_regularizer=kernel_regularizer))
    model.add(Flatten())
    model.add(Dense(1))
    model.compile(optimizer=optimizer, loss=loss, metrics=[custom_mape, custom_mae])
    return model

# %% [markdown]
# ## LSTM model

# %%
# Define a function to create a sequential CNN model
def create_lstm_model(units, n_steps_in, n_features, optimizer, loss, l1_reg=0, l2_reg=0):
    model = Sequential()
    model.add(LSTM(units=units, 
                     input_shape=(n_steps_in, n_features),
                  kernel_regularizer=l1_l2(l1=l1_reg, l2=l2_reg),  # Régularisation pour les poids d'entrée
                   recurrent_regularizer=l1_l2(l1=l1_reg, l2=l2_reg)  # Régularisation pour les poids récurrents
                  ))
    #model.add(Flatten())
    model.add(Dense(1))
    model.compile(optimizer=optimizer, loss=loss, metrics=[custom_mape, custom_mae])
    return model

# %% [markdown]
# ## Scale data

# %%
# Scale data between 0 and 1
def scale_data(data):
    scalers = {}
    data_normalized = data.copy()
    for column in data.columns:
        scaler = MinMaxScaler()
        data_normalized[column] = scaler.fit_transform(data[[column]])
        scalers[column] = scaler
    return data_normalized, scalers

# %% [markdown]
# ## Data transformation

# %%
# Define a function to transfrom data for CNN model
def transform_data_cnn(data_normalized, n_steps_in, start_date, end_date):    
    X, y, dates = [], [], []
    # Filter data based on the start and end dates
    data_filtered = data_normalized[start_date:end_date]
    # Create sequence data of n_steps_in days and n_steps_out days
    for i in range(n_steps_in, len(data_filtered)):
        X.append(data_filtered.iloc[i-n_steps_in:i])
        y.append(data_filtered.iloc[i]['tg1_traffic']) #0 because we just want to predict traffic
        dates.append(data_filtered.index[i])
    X, y, dates = np.array(X), np.array(y), np.array(dates)
    return X, y, dates

# %% [markdown]
# ## Transfer learning

# %%
def transfer_learning(X_train, y_train, n_steps_in, model_params, test_dates, y_test, model):
    # Initialize empty list to save forecast
    daily_predictions = []
    eight_day_predictions = [0] * len(test_dates)
    
    for i, date in enumerate(test_dates):
        
        # Get traffic of last day to update X_train
        if i == 0:
            new_traffic_point = y_train[-1] # for first forecast, need to take last traffic in train data
        else:
            new_traffic_point = y_test[i-1]
            
        # Create dummies for new datapoint
        current_date = test_dates[i] # forecast's day
        is_holiday = 1 if current_date in holidays_data['date'].values else 0

        # Create new data point with traffic and dummies
        new_data_point = [new_traffic_point, is_holiday]
        new_data_point_array=np.array([new_data_point])

        # Update X_train and y_train
        new_X = np.append(X_train[-1][1:], new_data_point_array, axis=0)
        X_train = np.append(X_train, [new_X], axis=0)
        y_train = np.append(y_train, [y_test[i]])
    
        # Quick update of model for learning transfer
        model.fit(X_train, y_train, epochs=1, verbose=0)

        # Make 1-day forecast
        
        prediction = model.predict(X_train[-1].reshape(1, n_steps_in, 2), verbose=0) 
        daily_predictions.append(prediction[0])
        
        # if current date is a Thursday, need to make a 8-day forecast
        if date.weekday() == 3:
            eight_days_data = X_train[-1]
            local_predictions = []
            for k in range(6):
                if i + k < len(test_dates):  # Check that the index does not go beyond the length of test_dates
                    current_date = test_dates[i+k]
                    is_holiday = 1 if current_date in holidays_data['date'].values else 0

                    # Créez un nouveau point de données avec le trafic et les dummies
                    new_prediction_point = [prediction[0][0], is_holiday]
                    new_prediction_point_array = np.array([new_prediction_point])
                    eight_days_data = np.append(eight_days_data[1:], new_prediction_point_array, axis=0)
                    prediction = model.predict(eight_days_data.reshape(1, n_steps_in, 2), verbose=0)
                    local_predictions.append(prediction[0])
            for j in range(min(5, len(local_predictions)-1)):
                index_to_assign = i+2+j
                if index_to_assign < len(eight_day_predictions):
                    eight_day_predictions[index_to_assign] = local_predictions[1+j][0]




    return daily_predictions, eight_day_predictions

# %% [markdown]
# ## Rescale data

# %%
def rescale_predictions(predictions, scaler):
    predictions_array = np.array(predictions)
    return scaler.inverse_transform(predictions_array.reshape(-1, 1))

# %% [markdown]
# ## Plot test results

# %%
def plot_test_results_from_df(df, title):
    plt.figure(figsize=(15, 7))
    plt.title(title)
    
    # Extraire les données du DataFrame
    test_dates = df.index
    y_test = df['Trafic TG1'].values
    y_test_forecast = df['Prévision globale'].values
    daily_forecast = df['Prévision journalière'].values
    weekly_forecast = df['Prévision hebdomadaire'].values

    # Remplir la zone d'erreur acceptable (+-5%)
    upper_bound = [val * 1.05 for val in y_test]
    lower_bound = [val * 0.95 for val in y_test]
    plt.fill_between(test_dates, upper_bound, lower_bound, color='blue', alpha=0.2)
    
    # Affichage de la prévision lancée d'un coup
    plt.plot(test_dates, y_test_forecast, label='Prévision globale', color='green', marker='o')
    
    # Affichage des prévisions quotidiennes
    plt.plot(test_dates, daily_forecast, label='Prévision journalière', color='red', marker='x')
    
    # Affichage des prévisions hebdomadaires
    plt.plot(test_dates, weekly_forecast, label='Prévision hebdomadaire', color='purple', marker='s')
    
    # Affichage du trafic réel    
    plt.plot(test_dates, y_test, label='Trafic réel', color='blue', linewidth=2)
    

    plt.xlabel('Date')
    plt.ylabel('Trafic')
    plt.legend()
    plt.grid(False)
    plt.show()

# %% [markdown]
# ## Plot train results

# %%
def plot_train_results_from_df(df, title):
    plt.figure(figsize=(15, 7))
    plt.title(title)
    
    # Extraire les données du DataFrame
    train_dates = df.index
    y_train = df['Trafic TG1'].values
    y_train_forecast = df['Prévision globale'].values

    # Remplir la zone d'erreur acceptable (+-5%)
    upper_bound = [val * 1.05 for val in y_train]
    lower_bound = [val * 0.95 for val in y_train]
    plt.fill_between(train_dates, upper_bound, lower_bound, color='blue', alpha=0.2)
    

    
    
    # Affichage du trafic réel    
    plt.plot(train_dates, y_train, label='Trafic réel', color='blue')
    # Affichage de la prévision lancée d'un coup
    plt.plot(train_dates, y_train_forecast, label='Prévision globale', color='green', linewidth = 2)
    

    plt.xlabel('Date')
    plt.ylabel('Trafic')
    plt.legend()
    plt.grid(False)
    plt.show()

# %% [markdown]
# ## Calculate MAPE

# %%
def calculate_mean_max_mape(actual, forecast):
    # Éviter la division par zéro et les erreurs NaN
    mask = actual != 0
    mape_values = np.abs((actual[mask] - forecast[mask]) / actual[mask]) * 100
    return np.mean(mape_values), np.max(mape_values)

def compute_mape_for_columns(df, actual_col, forecast_cols):
    mape_stats = {}
    for col in forecast_cols:
        valid_forecast_mask = ~df[col].isna()
        avg_mape, max_mape = calculate_mean_max_mape(df[actual_col][valid_forecast_mask], df[col][valid_forecast_mask])
        mape_stats[col] = {"avg_mape": avg_mape, "max_mape": max_mape}
    return mape_stats

# %% [markdown]
# ## Create tuner LSTM function

# %%
def build_lstm_model(hp):
    model = Sequential()
    
    # Définir un espace de recherche pour le nombre d'unités LSTM
    model.add(LSTM(
        units=hp.Int('lstm_units', min_value=32, max_value=512, step=32),
        input_shape=(n_steps_in, 2), # Remplacer par la forme de vos données d'entrée
        kernel_regularizer=l1_l2(
            l1=hp.Float('l1_regularization', min_value=1e-5, max_value=1e-2, sampling='LOG', default=1e-4),
            l2=hp.Float('l2_regularization', min_value=1e-5, max_value=1e-2, sampling='LOG', default=1e-4)
        )
    ))
    
    model.add(Dense(1, activation='sigmoid'))
    
    model.compile(
        optimizer='adam',
        loss=custom_mape,
        metrics=[custom_mape, custom_mae]
    )
    
    return model
# Define a function to create a sequential CNN model
def create_cnn_model(filters, kernel_size, activation, n_steps_in, n_features, optimizer, loss):
    model = Sequential()
    model.add(Conv1D(filters=filters, 
                     kernel_size=kernel_size, 
                     activation=activation, 
                     input_shape=(n_steps_in, n_features)))
    model.add(Conv1D(filters=filters, 
                     kernel_size=7, 
                     activation=activation))
    model.add(Flatten())
    model.add(Dense(1))
    model.compile(optimizer=optimizer, loss=loss, metrics=[custom_mape, custom_mae])
    return model

# %% [markdown]
# # Data preparation

# %% [markdown]
# Take out saturday and sunday of data, normalized the data before creating training and test dataset.
# <br>
# n_steps_in is the number of week $\times$ number of day in a week (here 5)

# %%
# Exclusion des jours de la semaine (samedi et dimanche)
data = data[(data.index.dayofweek != 5) & (data.index.dayofweek != 6)]

data_normalized, scaler = scale_data(data)

n_steps_in =260

X_train, y_train, train_dates = transform_data_cnn(data_normalized, 
                                                   n_steps_in,  
                                                   '2017-01-01', 
                                                   '2021-12-31')

X_test, y_test, test_dates = transform_data_cnn(data_normalized, 
                                                n_steps_in, 
                                                '2022-01-01', 
                                                '2023-01-15')

# %% [markdown]
# # Tuning

# %%
directory_to_delete = "keras_tuner_dir"
shutil.rmtree(directory_to_delete)

early_stop = EarlyStopping(monitor='val_custom_mape', patience=10, restore_best_weights=True)

# Définissez la recherche d'hyperparamètres
tuner = BayesianOptimization(
    build_lstm_model,
    objective=Objective(name='val_custom_mape', direction='min'),  # Nous optimisons sur la MAPE
    max_trials=100,  # nombre d'essais pour le tuning
    directory='keras_tuner_dir',  # dossier pour stocker les logs
    project_name='traffic_optimization'
)

# Recherche des meilleurs hyperparamètres
tuner.search(
    x=X_train,
    y=y_train,
    validation_data=(X_val, y_val),
    epochs=50, 
    callbacks=[early_stop]
)


best_model = tuner.get_best_models(num_models=1)[0]
best_hyperparameters = tuner.get_best_hyperparameters(num_trials=1)[0]

# %% [markdown]
# # Model creation

# %% [markdown]
# ## Model parameters

# %%
# CNN model parameters
model_params_CNN = {
    "filters": 64,
    "kernel_size": 7,
    "activation": "relu",
    "n_steps_in": n_steps_in,
    "n_features": 2,
    "optimizer": 'adam',
    "loss": custom_mape
}
# LSTM model parameters
model_params_LSTM = {
    "units": 64,
    "n_steps_in": n_steps_in,
    "n_features": 2,
    "optimizer": 'adam',
    "loss": custom_mape
}

# %% [markdown]
# ## Model creation

# %%
#cnn_model = create_cnn_model(**model_params_CNN)
lstm_model = create_lstm_model(**model_params_LSTM)
#history = cnn_model.fit(X_train, y_train, epochs=40)
history = lstm_model.fit(X_train, y_train, epochs=200)
# Historique des pertes
train_loss = history.history['loss']

epochs = range(1, len(train_loss) + 1)
plt.plot(epochs, train_loss, label='Training Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# ## Global forecast

# %%
y_train_forecast = cnn_model.predict(X_train)
y_test_forecast = cnn_model.predict(X_test)

# %% [markdown]
# ## Daily and Weekly Forecast

# %%
start_time = time.time()
daily_forecast, weekly_forecast = transfer_learning(X_train,y_train,n_steps_in,model_params,test_dates,y_test,cnn_model)
print("--- Transfert d'apprentissage: %s seconds ---" % (time.time() - start_time))

# %% [markdown]
# # Data analysis

# %% [markdown]
# ## Rescale data

# %%
y_train_forecast_rescaled = rescale_predictions(y_train_forecast, scaler['tg1_traffic'])
y_train_rescaled = rescale_predictions(y_train, scaler['tg1_traffic'])


y_test_forecast_rescaled = rescale_predictions(y_test_forecast, scaler['tg1_traffic'])
y_test_rescaled = rescale_predictions(y_test, scaler['tg1_traffic'])



daily_forecast_rescaled = rescale_predictions(daily_forecast, scaler['tg1_traffic'])
weekly_forecast_rescaled = rescale_predictions(weekly_forecast, scaler['tg1_traffic'])

# %% [markdown]
# ## Concatenate forecast in dataframe

# %%
data_train_forecast = pd.DataFrame({
    'Trafic TG1' : y_train_rescaled.flatten().tolist() ,
    'Prévision globale' : y_train_forecast_rescaled.flatten().tolist()
                            }, index = train_dates.tolist())

data_test_forecast = pd.DataFrame({
    'Trafic TG1' : y_test_rescaled.flatten().tolist() ,
    'Prévision globale' : y_test_forecast_rescaled.flatten().tolist(),
    'Prévision hebdomadaire' : weekly_forecast_rescaled.flatten().tolist(),
    'Prévision journalière' : daily_forecast_rescaled.flatten().tolist()  
                            }, index = test_dates.tolist())

# %% [markdown]
# ## Plot results

# %%
plot_test_results_from_df(data_test_forecast, 'Transfert d’apprentissage')

# %%
plot_train_results_from_df(data_train_forecast, "Résultats d'entraînement")

# %% [markdown]
# ## Metrics

# %%
# Utilisation de la fonction:
forecast_columns = ['Prévision globale', 'Prévision journalière', 'Prévision hebdomadaire']
mapes = compute_mape_for_columns(data_test_forecast, 'Trafic TG1', forecast_columns)

for col, mape_stats in mapes.items():
    avg_mape = mape_stats['avg_mape']
    max_mape = mape_stats['max_mape']
    print(f"MAPE moyen {col} : {avg_mape:.2f}%")
    print(f"MAPE max {col} : {max_mape:.2f}%")
    print("-" * 30)  # Juste pour séparer visuellement les différentes prévisions

# %%
# Utilisation de la fonction:
forecast_columns = ['Prévision globale']
mapes = compute_mape_for_columns(data_train_forecast, 'Trafic TG1', forecast_columns)

for col, mape_stats in mapes.items():
    avg_mape = mape_stats['avg_mape']
    max_mape = mape_stats['max_mape']
    print(f"MAPE moyen {col} : {avg_mape:.2f}%")
    print(f"MAPE max {col} : {max_mape:.2f}%")

# %% [markdown]
# # Tuning

# %% [markdown]
# ## Run CNN

# %%
def run_cnn(model_params):
    cnn_model = create_cnn_model(**model_params)
    history = cnn_model.fit(X_train, y_train, epochs=60)
    # Historique des pertes
    train_loss = history.history['loss']

    epochs = range(1, len(train_loss) + 1)

    plt.plot(epochs, train_loss, label='Training Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()
    
    y_train_forecast = cnn_model.predict(X_train)
    y_test_forecast = cnn_model.predict(X_test)

    daily_forecast, weekly_forecast = transfer_learning(X_train,y_train,n_steps_in,model_params,test_dates,y_test,cnn_model)
    
    y_train_forecast_rescaled = rescale_predictions(y_train_forecast, scaler['tg1_traffic'])
    y_train_rescaled = rescale_predictions(y_train, scaler['tg1_traffic'])


    y_test_forecast_rescaled = rescale_predictions(y_test_forecast, scaler['tg1_traffic'])
    y_test_rescaled = rescale_predictions(y_test, scaler['tg1_traffic'])



    daily_forecast_rescaled = rescale_predictions(daily_forecast, scaler['tg1_traffic'])
    weekly_forecast_rescaled = rescale_predictions(weekly_forecast, scaler['tg1_traffic'])
    
    data_train_forecast = pd.DataFrame({
    'Trafic TG1' : y_train_rescaled.flatten().tolist() ,
    'Prévision globale' : y_train_forecast_rescaled.flatten().tolist()
                            }, index = train_dates.tolist())

    data_test_forecast = pd.DataFrame({
    'Trafic TG1' : y_test_rescaled.flatten().tolist() ,
    'Prévision globale' : y_test_forecast_rescaled.flatten().tolist(),
    'Prévision hebdomadaire' : weekly_forecast_rescaled.flatten().tolist(),
    'Prévision journalière' : daily_forecast_rescaled.flatten().tolist()  
                            }, index = test_dates.tolist())
    
    plot_test_results_from_df(data_test_forecast, 'Transfert d’apprentissage')
    plot_train_results_from_df(data_train_forecast, "Résultats d'entraînement")
    
    mapes_train = {}
    mapes_test = {}
    
    # Calcul des MAPE pour les données d'entraînement
    forecast_columns_train = ['Prévision globale']
    mapes_train = compute_mape_for_columns(data_train_forecast, 'Trafic TG1', forecast_columns_train)
    
    for col, values in mapes_train.items():
        avg_mape = values['avg_mape']
        max_mape = values['max_mape']
        print(f"Train MAPE {col} - Average: {avg_mape:.2f}% | Max: {max_mape:.2f}%")
    
    # Calcul des MAPE pour les données de test
    forecast_columns_test = ['Prévision globale', 'Prévision journalière', 'Prévision hebdomadaire']
    mapes_test = compute_mape_for_columns(data_test_forecast, 'Trafic TG1', forecast_columns_test)
    
    for col, values in mapes_test.items():
        avg_mape = values['avg_mape']
        max_mape = values['max_mape']
        print(f"Test MAPE {col} - Average: {avg_mape:.2f}% | Max: {max_mape:.2f}%")

    return mapes_train, mapes_test

# %% [markdown]
# ## Run LSTM

# %%
def run_lstm(model_params):
    lstm_model = create_lstm_model(**model_params)
    history = lstm_model.fit(X_train, y_train, epochs=40, validation_data=(X_val, y_val))
    # Historique des pertes
    train_loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs = range(1, len(train_loss) + 1)

    plt.plot(epochs, train_loss, label='Training Loss')
    plt.plot(epochs, val_loss, label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()
    
    y_train_forecast = lstm_model.predict(X_train)
    y_val_forecast = lstm_model.predict(X_test)

    daily_forecast, weekly_forecast = transfer_learning(X_train,y_train,n_steps_in,model_params,val_dates,y_val,lstm_model)
    
    y_train_forecast_rescaled = rescale_predictions(y_train_forecast, scaler['tg1_traffic'])
    y_train_rescaled = rescale_predictions(y_train, scaler['tg1_traffic'])


    y_val_forecast_rescaled = rescale_predictions(y_val_forecast, scaler['tg1_traffic'])
    y_val_rescaled = rescale_predictions(y_val, scaler['tg1_traffic'])



    daily_forecast_rescaled = rescale_predictions(daily_forecast, scaler['tg1_traffic'])
    weekly_forecast_rescaled = rescale_predictions(weekly_forecast, scaler['tg1_traffic'])
    
    data_train_forecast = pd.DataFrame({
    'Trafic TG1' : y_train_rescaled.flatten().tolist() ,
    'Prévision globale' : y_train_forecast_rescaled.flatten().tolist()
                            }, index = train_dates.tolist())

    data_val_forecast = pd.DataFrame({
    'Trafic TG1' : y_val_rescaled.flatten().tolist() ,
    'Prévision globale' : y_val_forecast_rescaled.flatten().tolist(),
    'Prévision hebdomadaire' : weekly_forecast_rescaled.flatten().tolist(),
    'Prévision journalière' : daily_forecast_rescaled.flatten().tolist()  
                            }, index = test_dates.tolist())
    
    plot_test_results_from_df(data_val_forecast, 'Transfert d’apprentissage')
    plot_train_results_from_df(data_train_forecast, "Résultats d'entraînement")
    
    # Utilisation de la fonction:
    forecast_columns = ['Prévision globale', 'Prévision journalière', 'Prévision hebdomadaire']
    mapes = compute_mape_for_columns(data_val_forecast, 'Trafic TG1', forecast_columns)
    print(mapes)

    for col, values in mapes.items():
        avg_mape = values['avg_mape']
        max_mape = values['max_mape']
        print(f"MAPE {col} - Average: {avg_mape:.2f}% | Max: {max_mape:.2f}%")

        
    # Utilisation de la fonction:
    forecast_columns = ['Prévision globale']
    mapes = compute_mape_for_columns(data_train_forecast, 'Trafic TG1', forecast_columns)
    for col, values in mapes.items():
        avg_mape = values['avg_mape']
        max_mape = values['max_mape']
        print(f"MAPE {col} - Average: {avg_mape:.2f}% | Max: {max_mape:.2f}%")

# %% [markdown]
# ## Build CNN

# %%
# Paramètres du modèle

from datetime import datetime, timedelta

filters = [16, 64, 128]
kernels = [7, 14, 21]
list1 = [0, 1e-1, 1e-2, 1e-3, 1e-4]
list2 = [0, 1e-1, 1e-2, 1e-3, 1e-4]
reg_type = ["l1", "l2", "l1_l2"]




results = []

for filt in filters:
    for kernel in kernels:
            for reg in reg_type:
                # Si 'reg' est "l1", alors on n'a besoin que de parcourir les valeurs de "l1".
                # De même pour "l2". Si 'reg' est "l1_l2", alors on parcourt les deux listes.
                l1_values = list1 if reg in ['l1', 'l1_l2'] else [None]
                l2_values = list2 if reg in ['l2', 'l1_l2'] else [None]

                for L1 in l1_values:
                    for L2 in l2_values:
                        print(filt, kernel, reg, L1, L2)
                        model_params_cnn = {
                            "filters": filt,
                            "kernel_size": kernel,
                            "activation": "relu",
                            "n_steps_in": n_steps_in,
                            "n_features": 2,
                            "optimizer": 'adam',
                            "loss": custom_mape,
                            "reg_type" : reg,
                            "l1_value" : L1,
                            "l2_value" : L2
                        }

                        mapes_train, mapes_test = run_cnn(model_params_cnn)

                        results.append({
                            'filters': filt,
                            'kernel': kernel,
                            'reg_type': reg,
                            'l1_value': L1,
                            'l2_value': L2,
                            'mapes_train': mapes_train,
                            'mapes_test': mapes_test
                        })


results_df = pd.DataFrame(results)
# Out:
# 16 7 l1 0 None
# Epoch 1/60
# 2023-08-23 15:17:42.313146: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M1
# 2023-08-23 15:17:42.313221: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 8.00 GB
# 2023-08-23 15:17:42.313225: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 2.67 GB
# 2023-08-23 15:17:42.313492: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:303] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-08-23 15:17:42.313518: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:269] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# 2023-08-23 15:17:42.852259: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 33/33 [==============================] - 1s 8ms/step - loss: 42.9200 - custom_mape: 42.7646 - custom_mae: 13.3066
# Epoch 2/60
# 33/33 [==============================] - 0s 6ms/step - loss: 32.8154 - custom_mape: 34.1396 - custom_mae: 10.1472
# Epoch 3/60
# 33/33 [==============================] - 0s 6ms/step - loss: 28.6486 - custom_mape: 28.5438 - custom_mae: 10.1925
# Epoch 4/60
# 33/33 [==============================] - 0s 6ms/step - loss: 29.1911 - custom_mape: 29.5035 - custom_mae: 9.1247
# Epoch 5/60
# 33/33 [==============================] - 0s 6ms/step - loss: 25.3399 - custom_mape: 25.4014 - custom_mae: 9.4237
# Epoch 6/60
# 33/33 [==============================] - 0s 5ms/step - loss: 23.9800 - custom_mape: 23.9262 - custom_mae: 8.1158
# Epoch 7/60
# 33/33 [==============================] - 0s 6ms/step - loss: 22.8914 - custom_mape: 22.8485 - custom_mae: 7.8383
# Epoch 8/60
# 33/33 [==============================] - 0s 5ms/step - loss: 21.7605 - custom_mape: 21.7253 - custom_mae: 7.6071
# Epoch 9/60
# 33/33 [==============================] - 0s 6ms/step - loss: 20.3321 - custom_mape: 20.3138 - custom_mae: 6.9569
# Epoch 10/60
# 33/33 [==============================] - 0s 6ms/step - loss: 18.3412 - custom_mape: 18.3112 - custom_mae: 6.8627
# Epoch 11/60
# 33/33 [==============================] - 0s 6ms/step - loss: 19.6170 - custom_mape: 19.6510 - custom_mae: 7.0340
# Epoch 12/60
# 33/33 [==============================] - 0s 6ms/step - loss: 18.9237 - custom_mape: 18.9053 - custom_mae: 6.9808
# Epoch 13/60
# 33/33 [==============================] - 0s 6ms/step - loss: 18.9330 - custom_mape: 18.9722 - custom_mae: 6.3710
# Epoch 14/60
# 33/33 [==============================] - 0s 5ms/step - loss: 17.4892 - custom_mape: 17.5494 - custom_mae: 6.5617
# Epoch 15/60
# 33/33 [==============================] - 0s 5ms/step - loss: 19.9348 - custom_mape: 19.9809 - custom_mae: 7.0957
# Epoch 16/60
# 33/33 [==============================] - 0s 5ms/step - loss: 18.8388 - custom_mape: 18.8123 - custom_mae: 6.4164
# Epoch 17/60
# 33/33 [==============================] - 0s 6ms/step - loss: 15.7432 - custom_mape: 15.6967 - custom_mae: 5.8682
# Epoch 18/60
# 33/33 [==============================] - 0s 6ms/step - loss: 17.3268 - custom_mape: 17.2848 - custom_mae: 5.9967
# Epoch 19/60
# 33/33 [==============================] - 0s 6ms/step - loss: 14.0461 - custom_mape: 14.0923 - custom_mae: 5.7466
# Epoch 20/60
# 33/33 [==============================] - 0s 6ms/step - loss: 15.8547 - custom_mape: 15.8437 - custom_mae: 5.3410
# Epoch 21/60
# 33/33 [==============================] - 0s 5ms/step - loss: 15.3200 - custom_mape: 15.7007 - custom_mae: 5.5981
# Epoch 22/60
# 33/33 [==============================] - 0s 5ms/step - loss: 19.4913 - custom_mape: 19.4582 - custom_mae: 6.8449
# Epoch 23/60
# 33/33 [==============================] - 0s 5ms/step - loss: 16.3273 - custom_mape: 16.2956 - custom_mae: 5.9394
# Epoch 24/60
# 33/33 [==============================] - 0s 6ms/step - loss: 13.7351 - custom_mape: 13.7849 - custom_mae: 5.2957
# Epoch 25/60
# 33/33 [==============================] - 0s 5ms/step - loss: 15.0731 - custom_mape: 15.0708 - custom_mae: 5.4141
# Epoch 26/60
# 33/33 [==============================] - 0s 6ms/step - loss: 13.5526 - custom_mape: 13.5355 - custom_mae: 5.1796
# Epoch 27/60
# 33/33 [==============================] - 0s 6ms/step - loss: 13.7030 - custom_mape: 13.7063 - custom_mae: 5.0999
# Epoch 28/60
# 33/33 [==============================] - 0s 5ms/step - loss: 12.2417 - custom_mape: 12.1899 - custom_mae: 4.7047
# Epoch 29/60
# 33/33 [==============================] - 0s 6ms/step - loss: 14.6542 - custom_mape: 14.5875 - custom_mae: 5.1405
# Epoch 30/60
# 33/33 [==============================] - 0s 5ms/step - loss: 11.2995 - custom_mape: 11.2988 - custom_mae: 4.5519
# Epoch 31/60
# 33/33 [==============================] - 0s 6ms/step - loss: 12.9453 - custom_mape: 12.9257 - custom_mae: 4.4172
# Epoch 32/60
# 33/33 [==============================] - 0s 6ms/step - loss: 11.5731 - custom_mape: 11.6095 - custom_mae: 4.7809
# Epoch 33/60
# 33/33 [==============================] - 0s 6ms/step - loss: 13.9975 - custom_mape: 13.9614 - custom_mae: 4.6973
# Epoch 34/60
# 33/33 [==============================] - 0s 6ms/step - loss: 14.6603 - custom_mape: 14.5885 - custom_mae: 5.5054
# Epoch 35/60
# 33/33 [==============================] - 0s 6ms/step - loss: 12.6926 - custom_mape: 12.6934 - custom_mae: 4.5830
# Epoch 36/60
# 33/33 [==============================] - 0s 5ms/step - loss: 11.2261 - custom_mape: 11.2386 - custom_mae: 4.1819
# Epoch 37/60
# 33/33 [==============================] - 0s 5ms/step - loss: 12.4241 - custom_mape: 12.4372 - custom_mae: 4.6063
# Epoch 38/60
# 33/33 [==============================] - 0s 6ms/step - loss: 11.2707 - custom_mape: 11.5627 - custom_mae: 4.3717
# Epoch 39/60
# 33/33 [==============================] - 0s 6ms/step - loss: 16.0682 - custom_mape: 16.0250 - custom_mae: 5.4566
# Epoch 40/60
# 33/33 [==============================] - 0s 6ms/step - loss: 11.0417 - custom_mape: 11.0319 - custom_mae: 4.2557
# Epoch 41/60
# 33/33 [==============================] - 0s 6ms/step - loss: 13.6800 - custom_mape: 13.6650 - custom_mae: 4.7452
# Epoch 42/60
# 33/33 [==============================] - 0s 6ms/step - loss: 10.3430 - custom_mape: 10.3011 - custom_mae: 4.0389
# Epoch 43/60
# 33/33 [==============================] - 0s 5ms/step - loss: 11.9797 - custom_mape: 11.9097 - custom_mae: 4.1974
# Epoch 44/60
# 33/33 [==============================] - 0s 5ms/step - loss: 8.4452 - custom_mape: 8.4412 - custom_mae: 3.5498
# Epoch 45/60
# 33/33 [==============================] - 0s 6ms/step - loss: 10.5678 - custom_mape: 10.5420 - custom_mae: 3.6166
# Epoch 46/60
# 33/33 [==============================] - 0s 6ms/step - loss: 9.7803 - custom_mape: 9.8847 - custom_mae: 3.9716
# Epoch 47/60
# 33/33 [==============================] - 0s 5ms/step - loss: 10.7772 - custom_mape: 10.7484 - custom_mae: 3.5514
# Epoch 48/60
# 33/33 [==============================] - 0s 6ms/step - loss: 9.0867 - custom_mape: 9.0473 - custom_mae: 3.7535
# Epoch 49/60
# 33/33 [==============================] - 0s 5ms/step - loss: 10.4599 - custom_mape: 10.4947 - custom_mae: 3.3834
# Epoch 50/60
# 33/33 [==============================] - 0s 6ms/step - loss: 8.8556 - custom_mape: 8.8995 - custom_mae: 3.5444
# Epoch 51/60
# 33/33 [==============================] - 0s 5ms/step - loss: 10.3390 - custom_mape: 10.3800 - custom_mae: 3.4686
# Epoch 52/60
# 33/33 [==============================] - 0s 6ms/step - loss: 10.6461 - custom_mape: 10.6001 - custom_mae: 3.7993
# Epoch 53/60
# 33/33 [==============================] - 0s 6ms/step - loss: 9.7465 - custom_mape: 9.7427 - custom_mae: 3.3661
# Epoch 54/60
# 33/33 [==============================] - 0s 6ms/step - loss: 8.4387 - custom_mape: 8.3971 - custom_mae: 3.2071
# Epoch 55/60
# 33/33 [==============================] - 0s 6ms/step - loss: 9.2508 - custom_mape: 9.2609 - custom_mae: 3.1965
# Epoch 56/60
# 33/33 [==============================] - 0s 5ms/step - loss: 8.5842 - custom_mape: 8.5699 - custom_mae: 3.1448
# Epoch 57/60
# 33/33 [==============================] - 0s 6ms/step - loss: 8.2582 - custom_mape: 8.2484 - custom_mae: 3.0280
# Epoch 58/60
# 33/33 [==============================] - 0s 5ms/step - loss: 12.4835 - custom_mape: 12.4422 - custom_mae: 4.3076
# Epoch 59/60
# 33/33 [==============================] - 0s 6ms/step - loss: 7.9075 - custom_mape: 7.8952 - custom_mae: 3.0974
# Epoch 60/60
# 33/33 [==============================] - 0s 6ms/step - loss: 8.7867 - custom_mape: 8.7990 - custom_mae: 2.9627
# 33/33 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 19ms/step
# 2023-08-23 15:17:54.604855: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# Train MAPE Prévision globale - Average: 9.00% | Max: 519.56%
# Test MAPE Prévision globale - Average: 10.00% | Max: 22.28%
# Test MAPE Prévision journalière - Average: 14.94% | Max: 31.73%
# Test MAPE Prévision hebdomadaire - Average: 58.09% | Max: 100.00%
# 16 7 l2 None 0
# Epoch 1/60
#  5/33 [===>..........................] - ETA: 0s - loss: 55.8945 - custom_mape: 55.8945 - custom_mae: 21.6604
# 2023-08-23 15:17:57.971697: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 33/33 [==============================] - 1s 9ms/step - loss: 41.8347 - custom_mape: 41.5547 - custom_mae: 12.7094
# Epoch 2/60
# 33/33 [==============================] - 0s 6ms/step - loss: 30.5875 - custom_mape: 30.4828 - custom_mae: 9.4493
# Epoch 3/60
# 33/33 [==============================] - 0s 6ms/step - loss: 25.1717 - custom_mape: 25.1445 - custom_mae: 8.3400
# Epoch 4/60
# 33/33 [==============================] - 0s 6ms/step - loss: 25.2405 - custom_mape: 25.1274 - custom_mae: 7.7799
# Epoch 5/60
# 33/33 [==============================] - 0s 5ms/step - loss: 23.4135 - custom_mape: 23.4413 - custom_mae: 7.9209
# Epoch 6/60
# 33/33 [==============================] - 0s 6ms/step - loss: 20.4406 - custom_mape: 21.5973 - custom_mae: 7.2125
# Epoch 7/60
# 33/33 [==============================] - 0s 6ms/step - loss: 30.3933 - custom_mape: 30.2699 - custom_mae: 11.0344
# Epoch 8/60
# 33/33 [==============================] - 0s 6ms/step - loss: 27.9492 - custom_mape: 27.8497 - custom_mae: 7.7400
# Epoch 9/60
# 33/33 [==============================] - 0s 5ms/step - loss: 23.3338 - custom_mape: 23.3056 - custom_mae: 7.3147
# Epoch 10/60
# 33/33 [==============================] - 0s 6ms/step - loss: 19.4363 - custom_mape: 19.5098 - custom_mae: 6.8896
# Epoch 11/60
# 33/33 [==============================] - 0s 6ms/step - loss: 16.0872 - custom_mape: 16.1000 - custom_mae: 6.2942
# Epoch 12/60
# 33/33 [==============================] - 0s 5ms/step - loss: 17.3078 - custom_mape: 17.3501 - custom_mae: 6.1319
# Epoch 13/60
# 33/33 [==============================] - 0s 5ms/step - loss: 14.5585 - custom_mape: 14.5447 - custom_mae: 5.6912
# Epoch 14/60
# 33/33 [==============================] - 0s 6ms/step - loss: 16.6299 - custom_mape: 16.5244 - custom_mae: 5.4341
# Epoch 15/60
# 33/33 [==============================] - 0s 5ms/step - loss: 13.3691 - custom_mape: 13.3446 - custom_mae: 5.1421
# Epoch 16/60
# 33/33 [==============================] - 0s 6ms/step - loss: 15.2568 - custom_mape: 15.2031 - custom_mae: 5.2366
# Epoch 17/60
# 33/33 [==============================] - 0s 7ms/step - loss: 13.1063 - custom_mape: 13.0915 - custom_mae: 4.7054
# Epoch 18/60
# 33/33 [==============================] - 0s 5ms/step - loss: 13.0004 - custom_mape: 12.9889 - custom_mae: 4.8760
# Epoch 19/60
# 33/33 [==============================] - 0s 5ms/step - loss: 17.7632 - custom_mape: 17.6883 - custom_mae: 6.3562
# Epoch 20/60
# 33/33 [==============================] - 0s 5ms/step - loss: 12.4443 - custom_mape: 12.3975 - custom_mae: 4.7862
# Epoch 21/60
# 33/33 [==============================] - 0s 6ms/step - loss: 13.5577 - custom_mape: 13.5291 - custom_mae: 4.7149
# Epoch 22/60
# 33/33 [==============================] - 0s 5ms/step - loss: 11.2240 - custom_mape: 11.2196 - custom_mae: 4.3913
# Epoch 23/60
# 33/33 [==============================] - 0s 6ms/step - loss: 11.9481 - custom_mape: 11.9002 - custom_mae: 4.2514
# Epoch 24/60
# 33/33 [==============================] - 0s 5ms/step - loss: 11.2800 - custom_mape: 11.2647 - custom_mae: 4.3609
# Epoch 25/60
# 33/33 [==============================] - 0s 5ms/step - loss: 11.6659 - custom_mape: 11.6289 - custom_mae: 3.9661
# Epoch 26/60
# 33/33 [==============================] - 0s 5ms/step - loss: 10.2087 - custom_mape: 10.2049 - custom_mae: 4.1197
# Epoch 27/60
# 33/33 [==============================] - 0s 5ms/step - loss: 11.1393 - custom_mape: 11.1693 - custom_mae: 3.8031
# Epoch 28/60
# 33/33 [==============================] - 0s 6ms/step - loss: 9.7231 - custom_mape: 9.7294 - custom_mae: 3.9401
# Epoch 29/60
# 33/33 [==============================] - 0s 5ms/step - loss: 10.8708 - custom_mape: 10.8662 - custom_mae: 3.6550
# Epoch 30/60
# 33/33 [==============================] - 0s 5ms/step - loss: 10.5985 - custom_mape: 10.5868 - custom_mae: 3.9938
# Epoch 31/60
# 33/33 [==============================] - 0s 5ms/step - loss: 10.4254 - custom_mape: 11.2537 - custom_mae: 3.6348
# Epoch 32/60
# 33/33 [==============================] - 0s 6ms/step - loss: 10.9405 - custom_mape: 10.9495 - custom_mae: 3.9861
# Epoch 33/60
# 33/33 [==============================] - 0s 6ms/step - loss: 10.0914 - custom_mape: 10.0559 - custom_mae: 3.5874
# Epoch 34/60
# 33/33 [==============================] - 0s 6ms/step - loss: 9.1241 - custom_mape: 9.0957 - custom_mae: 3.2630
# Epoch 35/60
# 33/33 [==============================] - 0s 6ms/step - loss: 8.9737 - custom_mape: 9.0511 - custom_mae: 3.2510
# Epoch 36/60
# 33/33 [==============================] - 0s 6ms/step - loss: 9.9887 - custom_mape: 9.9491 - custom_mae: 3.7853
# Epoch 37/60
# 33/33 [==============================] - 0s 6ms/step - loss: 8.7559 - custom_mape: 8.7495 - custom_mae: 3.1657
# Epoch 38/60
# 33/33 [==============================] - 0s 6ms/step - loss: 8.7392 - custom_mape: 8.7095 - custom_mae: 3.2826
# Epoch 39/60
# 33/33 [==============================] - 0s 6ms/step - loss: 9.1950 - custom_mape: 9.1830 - custom_mae: 3.2904
# Epoch 40/60
# 33/33 [==============================] - 0s 6ms/step - loss: 9.3754 - custom_mape: 9.3460 - custom_mae: 3.4146
# Epoch 41/60
# 33/33 [==============================] - 0s 6ms/step - loss: 8.4346 - custom_mape: 8.4169 - custom_mae: 3.0267
# Epoch 42/60
# 33/33 [==============================] - 0s 5ms/step - loss: 8.2077 - custom_mape: 8.1700 - custom_mae: 3.2524
# Epoch 43/60
# 33/33 [==============================] - 0s 6ms/step - loss: 9.7088 - custom_mape: 9.6902 - custom_mae: 3.1253
# Epoch 44/60
# 33/33 [==============================] - 0s 6ms/step - loss: 7.3072 - custom_mape: 7.3142 - custom_mae: 2.9752
# Epoch 45/60
# 33/33 [==============================] - 0s 6ms/step - loss: 9.1774 - custom_mape: 9.1511 - custom_mae: 2.9318
# Epoch 46/60
# 33/33 [==============================] - 0s 6ms/step - loss: 6.7619 - custom_mape: 6.7499 - custom_mae: 2.8464
# Epoch 47/60
# 33/33 [==============================] - 0s 6ms/step - loss: 9.5554 - custom_mape: 9.6295 - custom_mae: 3.0779
# Epoch 48/60
# 33/33 [==============================] - 0s 5ms/step - loss: 6.8686 - custom_mape: 6.8518 - custom_mae: 2.8285
# Epoch 49/60
# 33/33 [==============================] - 0s 6ms/step - loss: 8.8257 - custom_mape: 8.8511 - custom_mae: 2.8945
# Epoch 50/60
# 33/33 [==============================] - 0s 6ms/step - loss: 6.2472 - custom_mape: 6.3692 - custom_mae: 2.4959
# Epoch 51/60
# 33/33 [==============================] - 0s 6ms/step - loss: 9.2283 - custom_mape: 9.1853 - custom_mae: 2.6965
# Epoch 52/60
# 33/33 [==============================] - 0s 5ms/step - loss: 7.5389 - custom_mape: 7.5150 - custom_mae: 2.6867
# Epoch 53/60
# 33/33 [==============================] - 0s 6ms/step - loss: 7.7593 - custom_mape: 7.7512 - custom_mae: 2.5568
# Epoch 54/60
# 33/33 [==============================] - 0s 5ms/step - loss: 7.3089 - custom_mape: 7.3077 - custom_mae: 2.7517
# Epoch 55/60
# 33/33 [==============================] - 0s 5ms/step - loss: 8.6090 - custom_mape: 8.5873 - custom_mae: 3.0614
# Epoch 56/60
# 33/33 [==============================] - 0s 6ms/step - loss: 5.8481 - custom_mape: 5.8571 - custom_mae: 2.2510
# Epoch 57/60
# 33/33 [==============================] - 0s 5ms/step - loss: 6.9135 - custom_mape: 6.8867 - custom_mae: 2.2490
# Epoch 58/60
# 33/33 [==============================] - 0s 6ms/step - loss: 6.9011 - custom_mape: 6.8699 - custom_mae: 2.4337
# Epoch 59/60
# 33/33 [==============================] - 0s 6ms/step - loss: 6.5997 - custom_mape: 6.5961 - custom_mae: 2.2037
# Epoch 60/60
# 33/33 [==============================] - 0s 6ms/step - loss: 5.5748 - custom_mape: 5.5866 - custom_mae: 2.1262
# 33/33 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 17ms/step
# 2023-08-23 15:18:09.718334: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# Train MAPE Prévision globale - Average: 5.95% | Max: 1235.73%
# Test MAPE Prévision globale - Average: 9.92% | Max: 17.27%
# Test MAPE Prévision journalière - Average: 14.19% | Max: 33.88%
# Test MAPE Prévision hebdomadaire - Average: 55.98% | Max: 100.00%
# 16 7 l1_l2 0 0
# Epoch 1/60
#  5/33 [===>..........................] - ETA: 0s - loss: 80.9588 - custom_mape: 80.9588 - custom_mae: 21.0000
# 2023-08-23 15:18:12.926728: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 33/33 [==============================] - 1s 9ms/step - loss: 37.0449 - custom_mape: 37.0280 - custom_mae: 12.2114
# Epoch 2/60
# 33/33 [==============================] - 0s 5ms/step - loss: 37.3255 - custom_mape: 37.1511 - custom_mae: 10.4233
# Epoch 3/60
# 33/33 [==============================] - 0s 5ms/step - loss: 29.7821 - custom_mape: 29.8328 - custom_mae: 8.9810
# Epoch 4/60
# 33/33 [==============================] - 0s 6ms/step - loss: 24.8212 - custom_mape: 24.7518 - custom_mae: 8.3700
# Epoch 5/60
# 33/33 [==============================] - 0s 5ms/step - loss: 22.9210 - custom_mape: 22.8704 - custom_mae: 7.3837
# Epoch 6/60
# 33/33 [==============================] - 0s 5ms/step - loss: 24.1385 - custom_mape: 24.0734 - custom_mae: 8.5616
# Epoch 7/60
# 33/33 [==============================] - 0s 5ms/step - loss: 19.0255 - custom_mape: 19.0089 - custom_mae: 7.0128
# Epoch 8/60
# 33/33 [==============================] - 0s 5ms/step - loss: 21.1778 - custom_mape: 21.0864 - custom_mae: 7.1455
# Epoch 9/60
# 33/33 [==============================] - 0s 6ms/step - loss: 23.4968 - custom_mape: 23.5011 - custom_mae: 7.7515
# Epoch 10/60
# 33/33 [==============================] - 0s 5ms/step - loss: 19.1544 - custom_mape: 19.2923 - custom_mae: 6.5447
# Epoch 11/60
# 33/33 [==============================] - 0s 5ms/step - loss: 16.4236 - custom_mape: 16.3950 - custom_mae: 6.1066
# Epoch 12/60
# 33/33 [==============================] - 0s 5ms/step - loss: 16.8070 - custom_mape: 16.8104 - custom_mae: 6.1590
# Epoch 13/60
# 33/33 [==============================] - 0s 6ms/step - loss: 18.0552 - custom_mape: 18.0132 - custom_mae: 6.4014
# Epoch 14/60
# 33/33 [==============================] - 0s 6ms/step - loss: 14.5741 - custom_mape: 14.7086 - custom_mae: 5.7371
# Epoch 15/60
# 33/33 [==============================] - 0s 5ms/step - loss: 17.9970 - custom_mape: 17.9763 - custom_mae: 6.3830
# Epoch 16/60
# 33/33 [==============================] - 0s 7ms/step - loss: 13.9658 - custom_mape: 13.9497 - custom_mae: 5.4028
# Epoch 17/60
# 33/33 [==============================] - 0s 6ms/step - loss: 16.8606 - custom_mape: 16.9396 - custom_mae: 5.6259
# Epoch 18/60
# 33/33 [==============================] - 0s 6ms/step - loss: 13.0387 - custom_mape: 13.0296 - custom_mae: 5.2514
# Epoch 19/60
# 33/33 [==============================] - 0s 6ms/step - loss: 16.4507 - custom_mape: 16.4775 - custom_mae: 5.4615
# Epoch 20/60
# 33/33 [==============================] - 0s 6ms/step - loss: 12.7471 - custom_mape: 12.7395 - custom_mae: 4.9405
# Epoch 21/60
# 33/33 [==============================] - 0s 5ms/step - loss: 14.2186 - custom_mape: 14.1857 - custom_mae: 4.7618
# Epoch 22/60
# 33/33 [==============================] - 0s 6ms/step - loss: 12.4600 - custom_mape: 12.4419 - custom_mae: 4.9022
# Epoch 23/60
# 33/33 [==============================] - 0s 5ms/step - loss: 15.4941 - custom_mape: 15.4753 - custom_mae: 4.9883
# Epoch 24/60
# 33/33 [==============================] - 0s 5ms/step - loss: 13.2051 - custom_mape: 13.2570 - custom_mae: 5.2029
# Epoch 25/60
# 33/33 [==============================] - 0s 5ms/step - loss: 14.1870 - custom_mape: 14.1380 - custom_mae: 4.9232
# Epoch 26/60
# 33/33 [==============================] - 0s 6ms/step - loss: 11.1856 - custom_mape: 11.2212 - custom_mae: 4.2796
# Epoch 27/60
# 33/33 [==============================] - 0s 5ms/step - loss: 13.9868 - custom_mape: 13.9436 - custom_mae: 4.8214
# Epoch 28/60
# 33/33 [==============================] - 0s 5ms/step - loss: 12.3156 - custom_mape: 12.2943 - custom_mae: 4.5277
# Epoch 29/60
# 33/33 [==============================] - 0s 5ms/step - loss: 11.9065 - custom_mape: 11.8749 - custom_mae: 4.3655
# Epoch 30/60
# 33/33 [==============================] - 0s 6ms/step - loss: 11.9083 - custom_mape: 11.8595 - custom_mae: 4.2449
# Epoch 31/60
# 33/33 [==============================] - 0s 6ms/step - loss: 10.4999 - custom_mape: 10.4958 - custom_mae: 3.8101
# Epoch 32/60
# 33/33 [==============================] - 0s 6ms/step - loss: 9.8548 - custom_mape: 9.8574 - custom_mae: 3.7197
# Epoch 33/60
# 33/33 [==============================] - 0s 6ms/step - loss: 11.1396 - custom_mape: 11.1572 - custom_mae: 4.1442
# Epoch 34/60
# 33/33 [==============================] - 0s 5ms/step - loss: 10.3335 - custom_mape: 10.3107 - custom_mae: 3.7475
# Epoch 35/60
# 33/33 [==============================] - 0s 5ms/step - loss: 11.3860 - custom_mape: 11.3893 - custom_mae: 4.2656
# Epoch 36/60
# 33/33 [==============================] - 0s 5ms/step - loss: 10.8433 - custom_mape: 10.8311 - custom_mae: 3.8303
# Epoch 37/60
# 33/33 [==============================] - 0s 6ms/step - loss: 9.1544 - custom_mape: 9.1233 - custom_mae: 3.6114
# Epoch 38/60
# 33/33 [==============================] - 0s 5ms/step - loss: 9.8717 - custom_mape: 9.8609 - custom_mae: 3.2744
# Epoch 39/60
# 33/33 [==============================] - 0s 5ms/step - loss: 7.8090 - custom_mape: 7.8359 - custom_mae: 3.2454
# Epoch 40/60
# 33/33 [==============================] - 0s 5ms/step - loss: 9.3774 - custom_mape: 9.3516 - custom_mae: 3.1481
# Epoch 41/60
# 33/33 [==============================] - 0s 6ms/step - loss: 8.3746 - custom_mape: 8.4189 - custom_mae: 3.4792
# Epoch 42/60
# 33/33 [==============================] - 0s 6ms/step - loss: 13.8706 - custom_mape: 13.8293 - custom_mae: 4.1862
# Epoch 43/60
# 33/33 [==============================] - 0s 5ms/step - loss: 7.9118 - custom_mape: 7.9092 - custom_mae: 3.2349
# Epoch 44/60
# 33/33 [==============================] - 0s 5ms/step - loss: 9.4112 - custom_mape: 9.6757 - custom_mae: 3.0350
# Epoch 45/60
# 33/33 [==============================] - 0s 5ms/step - loss: 9.5995 - custom_mape: 9.5872 - custom_mae: 3.7715
# Epoch 46/60
# 33/33 [==============================] - 0s 5ms/step - loss: 8.4566 - custom_mape: 8.4460 - custom_mae: 2.9313
# Epoch 47/60
# 33/33 [==============================] - 0s 6ms/step - loss: 7.9839 - custom_mape: 8.0024 - custom_mae: 3.0351
# Epoch 48/60
# 33/33 [==============================] - 0s 5ms/step - loss: 8.2514 - custom_mape: 8.2086 - custom_mae: 2.9164
# Epoch 49/60
# 33/33 [==============================] - 0s 6ms/step - loss: 7.4350 - custom_mape: 7.4236 - custom_mae: 2.7114
# Epoch 50/60
# 33/33 [==============================] - 0s 6ms/step - loss: 7.1471 - custom_mape: 7.1439 - custom_mae: 2.5487
# Epoch 51/60
# 33/33 [==============================] - 0s 6ms/step - loss: 7.9304 - custom_mape: 7.9027 - custom_mae: 2.8105
# Epoch 52/60
# 33/33 [==============================] - 0s 5ms/step - loss: 7.8994 - custom_mape: 7.9450 - custom_mae: 2.7823
# Epoch 53/60
# 33/33 [==============================] - 0s 5ms/step - loss: 8.1195 - custom_mape: 8.0943 - custom_mae: 2.6738
# Epoch 54/60
# 33/33 [==============================] - 0s 5ms/step - loss: 7.1199 - custom_mape: 7.1186 - custom_mae: 2.5298
# Epoch 55/60
# 33/33 [==============================] - 0s 6ms/step - loss: 7.4332 - custom_mape: 7.4122 - custom_mae: 2.4687
# Epoch 56/60
# 33/33 [==============================] - 0s 5ms/step - loss: 7.5194 - custom_mape: 7.5066 - custom_mae: 2.6804
# Epoch 57/60
# 33/33 [==============================] - 0s 5ms/step - loss: 8.3536 - custom_mape: 8.3149 - custom_mae: 2.8019
# Epoch 58/60
# 33/33 [==============================] - 0s 5ms/step - loss: 6.6938 - custom_mape: 6.6840 - custom_mae: 2.5622
# Epoch 59/60
# 33/33 [==============================] - 0s 5ms/step - loss: 7.6384 - custom_mape: 7.6131 - custom_mae: 2.4676
# Epoch 60/60
# 33/33 [==============================] - 0s 5ms/step - loss: 6.1157 - custom_mape: 6.1048 - custom_mae: 2.3777
# 33/33 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 24ms/step
# 2023-08-23 15:18:24.332420: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# Train MAPE Prévision globale - Average: 8.64% | Max: 1552.05%
# Test MAPE Prévision globale - Average: 9.38% | Max: 19.88%
# Test MAPE Prévision journalière - Average: 13.60% | Max: 38.65%
# Test MAPE Prévision hebdomadaire - Average: 60.27% | Max: 100.00%

# %%
print(results_df)
# Out:
#    filters  kernel reg_type  l1_value  l2_value  \
# 0       16       7       l1       0.0       NaN
# 1       16       7       l2       NaN       0.0
# 2       16       7    l1_l2       0.0       0.0
#
#                                          mapes_train  \
# 0  {'Prévision globale': {'avg_mape': 9.003313906...
# 1  {'Prévision globale': {'avg_mape': 5.949304263...
# 2  {'Prévision globale': {'avg_mape': 8.642218684...
#
#                                           mapes_test
# 0  {'Prévision globale': {'avg_mape': 9.999523676...
# 1  {'Prévision globale': {'avg_mape': 9.917576136...
# 2  {'Prévision globale': {'avg_mape': 9.376531520...

# %%
import pandas as pd

# Transformez les dictionnaires en colonnes
mapes_train_df = pd.json_normalize(results_df['mapes_train'])
mapes_test_df = pd.json_normalize(results_df['mapes_test'])

# Renommez les colonnes pour une meilleure clarté
mapes_train_df.columns = [col.replace("Prévision globale.", "train_") for col in mapes_train_df.columns]
mapes_test_df.columns = [col.replace("Prévision globale.", "test_") for col in mapes_test_df.columns]

# Supprimez les colonnes originales "mapes_train" et "mapes_test"
results_df.drop(columns=['mapes_train', 'mapes_test'], inplace=True)

# Concaténez les dataframes pour obtenir le résultat final
df = pd.concat([results_df, mapes_train_df, mapes_test_df], axis=1)


print(df)
# Out:
#    filters  kernel reg_type  l1_value  l2_value  train_avg_mape  \
# 0       16       7       l1       0.0       NaN        9.003314
# 1       16       7       l2       NaN       0.0        5.949304
# 2       16       7    l1_l2       0.0       0.0        8.642219
#
#    train_max_mape  test_avg_mape  test_max_mape  \
# 0      519.562174       9.999524      22.277433
# 1     1235.726929       9.917576      17.274842
# 2     1552.052544       9.376532      19.876551
#
#    Prévision journalière.avg_mape  Prévision journalière.max_mape  \
# 0                       14.935270                       31.725666
# 1                       14.190816                       33.876394
# 2                       13.595224                       38.653935
#
#    Prévision hebdomadaire.avg_mape  Prévision hebdomadaire.max_mape
# 0                        58.092134                            100.0
# 1                        55.978240                            100.0
# 2                        60.270491                            100.0
