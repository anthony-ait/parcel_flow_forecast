# %%
#Read dataset

import pandas as pd
import numpy as np

# Read main data
data = pd.read_excel('/Users/anthony/spyder-py3/ML/traffic_tg1.xlsx', index_col='date')
data.index = pd.to_datetime(data.index)

# Read holiday day data
holidays_data = pd.read_excel('/Users/anthony/spyder-py3/ML/public_holiday.xlsx')
holidays_data['date'] = pd.to_datetime(holidays_data['date'])

# %%
#Create dummies

# Create a dummy for holiday
data['is_holiday'] = data.index.isin(holidays_data['date']).astype(int)

# Create a dummy for sunday
data['is_sunday'] = (data.index.dayofweek == 6).astype(int)

# %%
#Transform data
from sklearn.preprocessing import MinMaxScaler

# Scale data between 0 and 1
def scale_data(data):
    scalers = {}
    data_normalized = data.copy()
    for column in data.columns:
        scaler = MinMaxScaler()
        data_normalized[column] = scaler.fit_transform(data[[column]])
        scalers[column] = scaler
    return data_normalized, scalers


# Define a function to transfrom data for CNN model
def transform_data_cnn(data_normalized, n_steps_in, start_date, end_date):    
    X, y, dates = [], [], []
    # Filter data based on the start and end dates
    data_filtered = data_normalized[start_date:end_date]
    # Create sequence data of n_steps_in days and n_steps_out days
    for i in range(n_steps_in, len(data_filtered)):
        X.append(data_filtered.iloc[i-n_steps_in:i])
        y.append(data_filtered.iloc[i]['tg1_traffic']) #0 because we just want to predict traffic
        dates.append(data_filtered.index[i])
    X, y, dates = np.array(X), np.array(y), np.array(dates)
    return X, y, dates

# %%
data_normalized, scaler = scale_data(data)

n_steps_in = 365


X_train, y_train, train_dates = transform_data_cnn(data_normalized, 
                                                   n_steps_in,  
                                                   '2017-01-01', 
                                                   '2019-12-31')
X_val, y_val, val_dates = transform_data_cnn(data_normalized,
                                             n_steps_in,
                                             '2020-01-01',
                                             '2021-12-31')
X_test, y_test, test_dates = transform_data_cnn(data_normalized, 
                                                n_steps_in, 
                                                '2022-01-01', 
                                                '2023-12-31')

# %%
# Keras Tuner

from keras_tuner.tuners import BayesianOptimization
from keras_tuner.engine.hyperparameters import HyperParameters
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, Flatten, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.optimizers import legacy as legacy_optimizers

# Define the model-building function
def build_model(hp):
    model = Sequential()
    
    # Hyperparamètres globaux
    activation = hp.Choice('activation', ['relu', 'elu', 'selu'])
    
    # Nouvel hyperparamètre pour le nombre de couches cachées
    num_hidden_layers = hp.Choice('num_hidden_layers', [1, 2, 3, 4, 7, 11, 18, 29, 47, 76])
    
    # Pour la première couche, nous définissons un input_shape
    filters = hp.Int(f'filters_layer_0', min_value=16, max_value=128, step=16)
    kernel_size = hp.Int(f'kernel_size_layer_0', min_value=3, max_value=15, step=2)
    
    model.add(Conv1D(filters=filters, 
                     kernel_size=kernel_size, 
                     activation=activation, 
                     input_shape=(n_steps_in, 3)))  # n_steps_in est fixé à 90
    
    # Ajout du nombre requis de couches cachées
    for i in range(1, num_hidden_layers):
        filters = hp.Int(f'filters_layer_{i}', min_value=16, max_value=128, step=16)
        kernel_size = hp.Int(f'kernel_size_layer_{i}', min_value=3, max_value=15, step=2)
        model.add(Conv1D(filters=filters, 
                         kernel_size=kernel_size, 
                         activation=activation))
    
    model.add(Flatten())
    model.add(Dense(1))
    
    optimizer = hp.Choice('optimizer', ['adam', 'rmsprop'])
    learning_rate = hp.Float('learning_rate', min_value=1e-4, max_value=1e-2, sampling='log')
    
    if optimizer == 'adam':
        opt = legacy_optimizers.Adam(learning_rate=learning_rate)
    elif optimizer == 'rmsprop':
        opt = legacy_optimizers.RMSprop(learning_rate=learning_rate)
    
    model.compile(optimizer=opt, loss='mse', metrics=['mae'])
    return model

# %%
from tensorflow.keras.callbacks import EarlyStopping

import shutil
#shutil.rmtree('keras_tuner_dir')


early_stop = EarlyStopping(monitor='val_mae', patience=10, restore_best_weights=True)

# Définissez la recherche d'hyperparamètres
tuner = BayesianOptimization(
    build_model,
    objective='val_mae',  # Nous optimisons sur la MAPE
    max_trials=100,  # nombre d'essais pour le tuning
    directory='keras_tuner_dir',  # dossier pour stocker les logs
    project_name='traffic_optimization'
)

# Recherche des meilleurs hyperparamètres
tuner.search(
    x=X_train,
    y=y_train,
    validation_data=(X_val, y_val),
    epochs=50, 
    callbacks=[early_stop]
)


best_model = tuner.get_best_models(num_models=1)[0]
best_hyperparameters = tuner.get_best_hyperparameters(num_trials=1)[0]
# Out:
# 2023-08-23 09:10:01.257270: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M1
# 2023-08-23 09:10:01.257305: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 8.00 GB
# 2023-08-23 09:10:01.257312: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 2.67 GB
# 2023-08-23 09:10:01.257863: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:303] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-08-23 09:10:01.258666: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:269] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Search: Running Trial #1
#
# Value             |Best Value So Far |Hyperparameter
# selu              |selu              |activation
# 18                |18                |num_hidden_layers
# 16                |16                |filters_layer_0
# 11                |11                |kernel_size_layer_0
# adam              |adam              |optimizer
# 0.00097271        |0.00097271        |learning_rate
#
# Epoch 1/50
# 2023-08-23 09:10:02.049544: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 23/23 [==============================] - ETA: 0s - loss: 1.0079 - mae: 0.7396
# 2023-08-23 09:10:03.790799: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 23/23 [==============================] - 3s 85ms/step - loss: 1.0079 - mae: 0.7396 - val_loss: 0.1345 - val_mae: 0.2974
# Epoch 2/50
# 23/23 [==============================] - 1s 66ms/step - loss: 0.1266 - mae: 0.2790 - val_loss: 0.0729 - val_mae: 0.2116
# Epoch 3/50
# 23/23 [==============================] - ETA: 0s - loss: 0.0457 - mae: 0.1709
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 19
#      10 tuner = BayesianOptimization(
#      11     build_model,
#      12     objective='val_mae',  # Nous optimisons sur la MAPE
#    (...)
#      15     project_name='traffic_optimization'
#      16 )
#      18 # Recherche des meilleurs hyperparamètres
# ---> 19 tuner.search(
#      20     x=X_train,
#      21     y=y_train,
#      22     validation_data=(X_val, y_val),
#      23     epochs=50,
#      24     callbacks=[early_stop]
#      25 )
#      28 best_model = tuner.get_best_models(num_models=1)[0]
#      29 best_hyperparameters = tuner.get_best_hyperparameters(num_trials=1)[0]
#
# File ~/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras_tuner/engine/base_tuner.py:230, in BaseTuner.search(self, *fit_args, **fit_kwargs)
#     227         continue
#     229     self.on_trial_begin(trial)
# --> 230     self._try_run_and_update_trial(trial, *fit_args, **fit_kwargs)
#     231     self.on_trial_end(trial)
#     232 self.on_search_end()
#
# File ~/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras_tuner/engine/base_tuner.py:270, in BaseTuner._try_run_and_update_trial(self, trial, *fit_args, **fit_kwargs)
#     268 def _try_run_and_update_trial(self, trial, *fit_args, **fit_kwargs):
#     269     try:
# --> 270         self._run_and_update_trial(trial, *fit_args, **fit_kwargs)
#     271         trial.status = trial_module.TrialStatus.COMPLETED
#     272         return
#
# File ~/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras_tuner/engine/base_tuner.py:235, in BaseTuner._run_and_update_trial(self, trial, *fit_args, **fit_kwargs)
#     234 def _run_and_update_trial(self, trial, *fit_args, **fit_kwargs):
# --> 235     results = self.run_trial(trial, *fit_args, **fit_kwargs)
#     236     if self.oracle.get_trial(trial.trial_id).metrics.exists(
#     237         self.oracle.objective.name
#     238     ):
#     239         # The oracle is updated by calling `self.oracle.update_trial()` in
#     240         # `Tuner.run_trial()`. For backward compatibility, we support this
#     241         # use case. No further action needed in this case.
#     242         warnings.warn(
#     243             "The use case of calling "
#     244             "`self.oracle.update_trial(trial_id, metrics)` "
#    (...)
#     250             stacklevel=2,
#     251         )
#
# File ~/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras_tuner/engine/tuner.py:287, in Tuner.run_trial(self, trial, *args, **kwargs)
#     285     callbacks.append(model_checkpoint)
#     286     copied_kwargs["callbacks"] = callbacks
# --> 287     obj_value = self._build_and_fit_model(trial, *args, **copied_kwargs)
#     289     histories.append(obj_value)
#     290 return histories
#
# File ~/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras_tuner/engine/tuner.py:214, in Tuner._build_and_fit_model(self, trial, *args, **kwargs)
#     212 hp = trial.hyperparameters
#     213 model = self._try_build(hp)
# --> 214 results = self.hypermodel.fit(hp, model, *args, **kwargs)
#     215 tuner_utils.validate_trial_results(
#     216     results, self.oracle.objective, "HyperModel.fit()"
#     217 )
#     218 return results
#
# File ~/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras_tuner/engine/hypermodel.py:144, in HyperModel.fit(self, hp, model, *args, **kwargs)
#     120 def fit(self, hp, model, *args, **kwargs):
#     121     """Train the model.
#     122
#     123     Args:
#    (...)
#     142         If return a float, it should be the `objective` value.
#     143     """
# --> 144     return model.fit(*args, **kwargs)
#
# File ~/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/src/engine/training.py:1809, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1804     val_logs = {
#    1805         "val_" + name: val for name, val in val_logs.items()
#    1806     }
#    1807     epoch_logs.update(val_logs)
# -> 1809 callbacks.on_epoch_end(epoch, epoch_logs)
#    1810 training_logs = epoch_logs
#    1811 if self.stop_training:
#
# File ~/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/src/callbacks.py:453, in CallbackList.on_epoch_end(self, epoch, logs)
#     451 logs = self._process_logs(logs)
#     452 for callback in self.callbacks:
# --> 453     callback.on_epoch_end(epoch, logs)
#
# File ~/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras_tuner/engine/tuner_utils.py:172, in SaveBestEpoch.on_epoch_end(self, epoch, logs)
#     170 if self.objective.better_than(current_value, self.best_value):
#     171     self.best_value = current_value
# --> 172     self._save_model()
#
# File ~/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras_tuner/engine/tuner_utils.py:179, in SaveBestEpoch._save_model(self)
#     174 def _save_model(self):
#     175     # Create temporary saved model files on non-chief workers.
#     176     write_filepath = file_utils.write_filepath(
#     177         self.filepath, self.model.distribute_strategy
#     178     )
# --> 179     self.model.save_weights(write_filepath)
#     180     # Remove temporary saved model files on non-chief workers.
#     181     file_utils.remove_temp_dir_with_filepath(
#     182         write_filepath, self.model.distribute_strategy
#     183     )
#
# File ~/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/src/engine/training.py:3072, in Model.save_weights(self, filepath, overwrite, save_format, options)
#    3008 @traceback_utils.filter_traceback
#    3009 def save_weights(
#    3010     self, filepath, overwrite=True, save_format=None, options=None
#    3011 ):
#    3012     """Saves all layer weights.
#    3013
#    3014     Either saves in HDF5 or in TensorFlow format based on the `save_format`
#    (...)
#    3070             HDF5 format.
#    3071     """
# -> 3072     saving_api.save_weights(
#    3073         self,
#    3074         filepath=filepath,
#    3075         overwrite=overwrite,
#    3076         save_format=save_format,
#    3077         options=options,
#    3078     )
#
# File ~/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/src/saving/saving_api.py:256, in save_weights(model, filepath, overwrite, **kwargs)
#     254     saving_lib.save_weights_only(model, filepath)
#     255 else:
# --> 256     legacy_sm_saving_lib.save_weights(
#     257         model, filepath, overwrite=overwrite, **kwargs
#     258     )
#
# File ~/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/src/saving/legacy/save.py:375, in save_weights(model, filepath, overwrite, save_format, options)
#     372 if not tf.executing_eagerly():
#     373     # Call `get_session` to initialize any uninitialized variables.
#     374     backend.get_session()
# --> 375 model._checkpoint.write(filepath, options=options)
#     377 # Record this checkpoint so it's visible from
#     378 # tf.train.latest_checkpoint.
#     379 tf.__internal__.train.update_checkpoint_state(
#     380     save_dir=os.path.dirname(filepath),
#     381     model_checkpoint_path=filepath,
#     382     save_relative_paths=True,
#     383     all_model_checkpoint_paths=[filepath],
#     384 )
#
# File ~/miniconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/checkpoint/checkpoint.py:2272, in Checkpoint.write(self, file_prefix, options)
#    2270 if isinstance(file_prefix, os.PathLike):
#    2271   file_prefix = os.fspath(file_prefix)
# -> 2272 return self._write(file_prefix, options)
#
# File ~/miniconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/checkpoint/checkpoint.py:2324, in Checkpoint._write(self, file_prefix, options, write_done_callback)
#    2322 start_time = time.time()
#    2323 options = options or checkpoint_options.CheckpointOptions()
# -> 2324 output = self._saver.save(file_prefix=file_prefix, options=options)
#    2325 output = _convert_file_name_tensor_to_string(output)
#    2327 if write_done_callback:
#
# File ~/miniconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/checkpoint/checkpoint.py:1315, in TrackableSaver.save(self, file_prefix, checkpoint_number, session, options)
#    1312 if not tensor_util.is_tensor(file_prefix):
#    1313   file_io.recursive_create_dir(os.path.dirname(file_prefix))
# -> 1315 save_path, new_feed_additions = self._save_cached_when_graph_building(
#    1316     file_prefix_tensor, object_graph_tensor, options)
#    1318 if new_feed_additions:
#    1319   feed_dict.update(new_feed_additions)
#
# File ~/miniconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/checkpoint/checkpoint.py:1243, in TrackableSaver._save_cached_when_graph_building(self, file_prefix, object_graph_tensor, options)
#    1226 def _save_cached_when_graph_building(self, file_prefix, object_graph_tensor,
#    1227                                      options):
#    1228   """Create or retrieve save ops.
#    1229
#    1230   Args:
#    (...)
#    1240     checkpoint. When executing eagerly only the first argument is meaningful.
#    1241   """
#    1242   serialized_tensors, feed_additions, registered_savers, graph_proto = (
# -> 1243       self._gather_serialized_tensors(object_graph_tensor))
#    1245   if (self._last_save_object_graph != graph_proto
#    1246       # When executing eagerly, we need to re-create SaveableObjects each
#    1247       # time save() is called so they pick up new Tensors passed to their
#    1248       # constructors. That means the Saver needs to be copied with a new
#    1249       # var_list.
#    1250       or context.executing_eagerly() or ops.inside_function()):
#    1251     saver = functional_saver.MultiDeviceSaver(serialized_tensors,
#    1252                                               registered_savers)
#
# File ~/miniconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/checkpoint/checkpoint.py:1204, in TrackableSaver._gather_serialized_tensors(self, object_graph_tensor)
#    1201 def _gather_serialized_tensors(self, object_graph_tensor=None):
#    1202   """Gathers tensors to save to ckpt and includes the object graph proto."""
#    1203   serialized_tensors, feed_additions, registered_savers, graph_proto = (
# -> 1204       save_util.serialize_graph_view(self._graph_view,
#    1205                                      self._object_map,
#    1206                                      cache=self._cache))
#    1208   if self._saveables_cache is not None:
#    1209     # Store saveables cache for restoration purposes.
#    1210     self._saveables_cache = (
#    1211         saveable_object_util.serialized_tensors_to_saveable_cache(
#    1212             serialized_tensors))
#
# File ~/miniconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/checkpoint/save_util.py:303, in serialize_graph_view(graph_view, object_map, call_with_mapped_captures, cache)
#     297 """Gathers serialization objects, and creates a TrackableObjectGraph proto."""
#     298 # There are 3 types of checkpoint serialization types supported:
#     299 # 1. Trackables that override `Trackable._serialize_to_tensor()`.
#     300 # 2. PythonState: A special type of Trackable that serializes a Python string.
#     301 # 3. Registered Trackable Savers: For objects that need to define advanced
#     302 #    checkpointing operations not supported by (1) or (2).
# --> 303 trackable_data, node_ids = _gather_trackable_data(graph_view, object_map)
#     304 tensor_trackables, pystate_trackables, registered_trackables = (
#     305     _split_trackables(trackable_data))
#     307 object_graph_proto = _fill_object_graph_proto(trackable_data)
#
# File ~/miniconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/checkpoint/save_util.py:95, in _gather_trackable_data(graph_view, object_map)
#      93 for node_id, node in enumerate(trackable_objects):
#      94   node_ids[node] = node_id
# ---> 95 slot_variables = util.serialize_slot_variables(
#      96     trackable_objects=trackable_objects,
#      97     node_ids=node_ids,
#      98     object_names=object_names)
#      99 trackable_data = []
#     100 for trackable in trackable_objects:
#
# File ~/miniconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/checkpoint/util.py:38, in serialize_slot_variables(trackable_objects, node_ids, object_names)
#      35 for original_variable_node_id, original_variable in enumerate(
#      36     non_slot_objects):
#      37   try:
# ---> 38     slot_variable = trackable.get_slot(original_variable, slot_name)
#      39   except (AttributeError, KeyError):
#      40     slot_variable = None
#
# File ~/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/src/optimizers/legacy/optimizer_v2.py:1087, in OptimizerV2.get_slot(self, var, slot_name)
#    1086 def get_slot(self, var, slot_name):
# -> 1087     var_key = _var_key(var)
#    1088     slot_dict = self._slots[var_key]
#    1089     slot_variable = slot_dict[slot_name]
#
# File ~/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/src/optimizers/legacy/optimizer_v2.py:1671, in _var_key(var)
#    1668 if hasattr(var, "_distributed_container"):
#    1669     var = var._distributed_container()
#    1670 elif (
# -> 1671     tf_utils.is_extension_type(var)
#    1672     and hasattr(var, "handle")
#    1673     and hasattr(var.handle, "_distributed_container")
#    1674 ):
#    1675     # For ResourceVariables, the _distributed_container attribute
#    1676     # is added to their handle tensors.
#    1677     var = var.handle._distributed_container()
#    1678 if getattr(var, "_in_graph_mode", False):
#
# File ~/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/src/utils/tf_utils.py:401, in is_extension_type(tensor)
#     387 def is_extension_type(tensor):
#     388     """Returns whether a tensor is of an ExtensionType.
#     389
#     390     github.com/tensorflow/community/pull/269
#    (...)
#     399       True if the tensor is an extension type object, false if not.
#     400     """
# --> 401     return isinstance(tensor, tf.__internal__.CompositeTensor)
#
# File ~/miniconda3/envs/tensorflow/lib/python3.10/abc.py:119, in ABCMeta.__instancecheck__(cls, instance)
#     117 def __instancecheck__(cls, instance):
#     118     """Override for isinstance(instance, cls)."""
# --> 119     return _abc_instancecheck(cls, instance)
#
# KeyboardInterrupt:

# %%
# Get the best model
best_model = tuner.get_best_models(num_models=1)[0]
best_hyperparameters = tuner.get_best_hyperparameters(num_trials=1)[0]
print(best_hyperparameters.values)


# Predict on the training and validation data
y_train_pred = best_model.predict(X_train)
y_val_pred = best_model.predict(X_val)


# Get the scaler for the target variable
target_scaler = scaler['tg1_traffic']

# Rescale predictions
y_train_pred_rescaled = target_scaler.inverse_transform(y_train_pred)
y_val_pred_rescaled = target_scaler.inverse_transform(y_val_pred)

# Rescale true values
y_train_rescaled = target_scaler.inverse_transform(y_train.reshape(-1, 1))
y_val_rescaled = target_scaler.inverse_transform(y_val.reshape(-1, 1))

import matplotlib.pyplot as plt

# Plot for training data
plt.figure(figsize=(15, 6))

plt.subplot(1, 2, 1)
plt.plot(train_dates, y_train_rescaled, label='True Values', color='blue')
plt.plot(train_dates, y_train_pred_rescaled, label='Predictions', color='red', linestyle='--')
plt.title('Training Data: True vs Predicted')
plt.legend()

# Plot for validation data
plt.subplot(1, 2, 2)
plt.plot(val_dates, y_val_rescaled, label='True Values', color='blue')
plt.plot(val_dates, y_val_pred_rescaled, label='Predictions', color='red', linestyle='--')
plt.title('Validation Data: True vs Predicted')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# WARNING:tensorflow:Detecting that an object or model or tf.train.Checkpoint is being deleted with unrestored values. See the following logs for the specific values in question. To silence these warnings, use `status.expect_partial()`. See https://www.tensorflow.org/api_docs/python/tf/train/Checkpoint#restorefor details about the status object returned by the restore function.
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.iter
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.beta_1
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.beta_2
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.decay
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.learning_rate
# WARNING:tensorflow:Detecting that an object or model or tf.train.Checkpoint is being deleted with unrestored values. See the following logs for the specific values in question. To silence these warnings, use `status.expect_partial()`. See https://www.tensorflow.org/api_docs/python/tf/train/Checkpoint#restorefor details about the status object returned by the restore function.
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.iter
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.beta_1
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.beta_2
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.decay
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.learning_rate
# {'activation': 'relu', 'num_hidden_layers': 11, 'filters_layer_0': 48, 'kernel_size_layer_0': 13, 'optimizer': 'adam', 'learning_rate': 0.00011100991873692364, 'filters_layer_1': 128, 'kernel_size_layer_1': 15, 'filters_layer_2': 112, 'kernel_size_layer_2': 13, 'filters_layer_3': 32, 'kernel_size_layer_3': 7, 'filters_layer_4': 32, 'kernel_size_layer_4': 5, 'filters_layer_5': 16, 'kernel_size_layer_5': 13, 'filters_layer_6': 64, 'kernel_size_layer_6': 13, 'filters_layer_7': 32, 'kernel_size_layer_7': 9, 'filters_layer_8': 64, 'kernel_size_layer_8': 11, 'filters_layer_9': 128, 'kernel_size_layer_9': 7, 'filters_layer_10': 128, 'kernel_size_layer_10': 11, 'filters_layer_11': 64, 'kernel_size_layer_11': 15, 'filters_layer_12': 80, 'kernel_size_layer_12': 9, 'filters_layer_13': 48, 'kernel_size_layer_13': 15, 'filters_layer_14': 80, 'kernel_size_layer_14': 7, 'filters_layer_15': 32, 'kernel_size_layer_15': 9, 'filters_layer_16': 32, 'kernel_size_layer_16': 7, 'filters_layer_17': 128, 'kernel_size_layer_17': 7, 'filters_layer_18': 96, 'kernel_size_layer_18': 7, 'filters_layer_19': 112, 'kernel_size_layer_19': 9, 'filters_layer_20': 128, 'kernel_size_layer_20': 7, 'filters_layer_21': 48, 'kernel_size_layer_21': 7, 'filters_layer_22': 128, 'kernel_size_layer_22': 5, 'filters_layer_23': 96, 'kernel_size_layer_23': 15, 'filters_layer_24': 96, 'kernel_size_layer_24': 3, 'filters_layer_25': 128, 'kernel_size_layer_25': 15, 'filters_layer_26': 32, 'kernel_size_layer_26': 15, 'filters_layer_27': 96, 'kernel_size_layer_27': 11, 'filters_layer_28': 96, 'kernel_size_layer_28': 7, 'filters_layer_29': 16, 'kernel_size_layer_29': 9, 'filters_layer_30': 48, 'kernel_size_layer_30': 7, 'filters_layer_31': 16, 'kernel_size_layer_31': 15, 'filters_layer_32': 80, 'kernel_size_layer_32': 15, 'filters_layer_33': 64, 'kernel_size_layer_33': 11, 'filters_layer_34': 128, 'kernel_size_layer_34': 15, 'filters_layer_35': 80, 'kernel_size_layer_35': 13, 'filters_layer_36': 32, 'kernel_size_layer_36': 11, 'filters_layer_37': 64, 'kernel_size_layer_37': 15, 'filters_layer_38': 48, 'kernel_size_layer_38': 3, 'filters_layer_39': 80, 'kernel_size_layer_39': 3, 'filters_layer_40': 48, 'kernel_size_layer_40': 11, 'filters_layer_41': 128, 'kernel_size_layer_41': 7, 'filters_layer_42': 96, 'kernel_size_layer_42': 15, 'filters_layer_43': 64, 'kernel_size_layer_43': 15, 'filters_layer_44': 16, 'kernel_size_layer_44': 9, 'filters_layer_45': 32, 'kernel_size_layer_45': 5, 'filters_layer_46': 48, 'kernel_size_layer_46': 7, 'filters_layer_47': 96, 'kernel_size_layer_47': 5, 'filters_layer_48': 128, 'kernel_size_layer_48': 9, 'filters_layer_49': 16, 'kernel_size_layer_49': 3, 'filters_layer_50': 64, 'kernel_size_layer_50': 11, 'filters_layer_51': 16, 'kernel_size_layer_51': 13, 'filters_layer_52': 128, 'kernel_size_layer_52': 3, 'filters_layer_53': 128, 'kernel_size_layer_53': 15, 'filters_layer_54': 48, 'kernel_size_layer_54': 5, 'filters_layer_55': 80, 'kernel_size_layer_55': 13, 'filters_layer_56': 96, 'kernel_size_layer_56': 3, 'filters_layer_57': 112, 'kernel_size_layer_57': 3, 'filters_layer_58': 16, 'kernel_size_layer_58': 11, 'filters_layer_59': 32, 'kernel_size_layer_59': 7, 'filters_layer_60': 128, 'kernel_size_layer_60': 7, 'filters_layer_61': 16, 'kernel_size_layer_61': 11}
# 2023-08-14 10:48:18.215645: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 23/23 [==============================] - 2s 46ms/step
# 12/12 [==============================] - 1s 51ms/step

# %%
def calculate_mape(y_true, y_pred):
    # Filter out the entries for which y_true is zero
    non_zero_mask = y_true != 0
    y_true = y_true[non_zero_mask]
    y_pred = y_pred[non_zero_mask]
    
    # Calculate the MAPE
    mape = 100 * np.mean(np.abs((y_true - y_pred) / y_true))
    return mape
# Calculate MAPE for training data
mape_train = calculate_mape(y_train_rescaled.flatten(), y_train_pred_rescaled.flatten())

# Calculate MAPE for validation data
mape_val = calculate_mape(y_val_rescaled.flatten(), y_val_pred_rescaled.flatten())

print(f"MAPE on Training Data: {mape_train:.2f}%")
print(f"MAPE on Validation Data: {mape_val:.2f}%")
# Out:
# MAPE on Training Data: 36.72%
# MAPE on Validation Data: 20.74%

# %%
# Afficher un résumé des résultats
tuner.results_summary()
# Out:
# Results summary
# Results in keras_tuner_dir/traffic_optimization
# Showing 10 best trials
# Objective(name="val_mae", direction="min")
#
# Trial 084 summary
# Hyperparameters:
# activation: relu
# num_hidden_layers: 11
# filters_layer_0: 48
# kernel_size_layer_0: 13
# optimizer: adam
# learning_rate: 0.00011100991873692364
# filters_layer_1: 128
# kernel_size_layer_1: 15
# filters_layer_2: 112
# kernel_size_layer_2: 13
# filters_layer_3: 32
# kernel_size_layer_3: 7
# filters_layer_4: 32
# kernel_size_layer_4: 5
# filters_layer_5: 16
# kernel_size_layer_5: 13
# filters_layer_6: 64
# kernel_size_layer_6: 13
# filters_layer_7: 32
# kernel_size_layer_7: 9
# filters_layer_8: 64
# kernel_size_layer_8: 11
# filters_layer_9: 128
# kernel_size_layer_9: 7
# filters_layer_10: 128
# kernel_size_layer_10: 11
# filters_layer_11: 64
# kernel_size_layer_11: 15
# filters_layer_12: 80
# kernel_size_layer_12: 9
# filters_layer_13: 48
# kernel_size_layer_13: 15
# filters_layer_14: 80
# kernel_size_layer_14: 7
# filters_layer_59: 128
# kernel_size_layer_59: 11
# filters_layer_60: 16
# kernel_size_layer_60: 9
# filters_layer_61: 96
# kernel_size_layer_61: 9
# Score: 0.06308075785636902
#
# Trial 098 summary
# Hyperparameters:
# activation: elu
# num_hidden_layers: 29
# filters_layer_0: 112
# kernel_size_layer_0: 3
# optimizer: adam
# learning_rate: 0.000485363152177768
# filters_layer_1: 80
# kernel_size_layer_1: 13
# filters_layer_2: 16
# kernel_size_layer_2: 15
# filters_layer_3: 112
# kernel_size_layer_3: 3
# filters_layer_4: 32
# kernel_size_layer_4: 15
# filters_layer_5: 48
# kernel_size_layer_5: 15
# filters_layer_6: 80
# kernel_size_layer_6: 5
# filters_layer_7: 112
# kernel_size_layer_7: 3
# filters_layer_8: 16
# kernel_size_layer_8: 5
# filters_layer_9: 48
# kernel_size_layer_9: 15
# filters_layer_10: 64
# kernel_size_layer_10: 13
# filters_layer_11: 96
# kernel_size_layer_11: 15
# filters_layer_12: 128
# kernel_size_layer_12: 9
# filters_layer_13: 128
# kernel_size_layer_13: 11
# filters_layer_14: 32
# kernel_size_layer_14: 11
# filters_layer_15: 32
# kernel_size_layer_15: 13
# filters_layer_16: 80
# kernel_size_layer_16: 5
# filters_layer_17: 32
# kernel_size_layer_17: 5
# filters_layer_18: 64
# kernel_size_layer_18: 3
# filters_layer_19: 112
# kernel_size_layer_19: 9
# filters_layer_20: 96
# kernel_size_layer_20: 15
# filters_layer_21: 64
# kernel_size_layer_21: 7
# filters_layer_22: 96
# kernel_size_layer_22: 5
# filters_layer_23: 16
# kernel_size_layer_23: 5
# filters_layer_24: 32
# kernel_size_layer_24: 3
# filters_layer_25: 128
# kernel_size_layer_25: 3
# filters_layer_26: 32
# kernel_size_layer_26: 9
# filters_layer_27: 48
# kernel_size_layer_27: 7
# filters_layer_28: 112
# kernel_size_layer_28: 5
# filters_layer_29: 64
# kernel_size_layer_29: 7
# filters_layer_30: 128
# kernel_size_layer_30: 11
# filters_layer_31: 16
# kernel_size_layer_31: 13
# filters_layer_32: 128
# kernel_size_layer_32: 5
# filters_layer_33: 32
# kernel_size_layer_33: 3
# filters_layer_34: 80
# kernel_size_layer_34: 5
# filters_layer_35: 32
# kernel_size_layer_35: 13
# filters_layer_36: 128
# kernel_size_layer_36: 7
# filters_layer_37: 80
# kernel_size_layer_37: 11
# filters_layer_38: 128
# kernel_size_layer_38: 9
# filters_layer_39: 64
# kernel_size_layer_39: 15
# filters_layer_40: 128
# kernel_size_layer_40: 5
# filters_layer_41: 112
# kernel_size_layer_41: 11
# filters_layer_42: 128
# kernel_size_layer_42: 15
# filters_layer_43: 96
# kernel_size_layer_43: 13
# filters_layer_44: 32
# kernel_size_layer_44: 7
# filters_layer_45: 16
# kernel_size_layer_45: 13
# filters_layer_46: 112
# kernel_size_layer_46: 7
# filters_layer_47: 64
# kernel_size_layer_47: 7
# filters_layer_48: 16
# kernel_size_layer_48: 5
# filters_layer_49: 96
# kernel_size_layer_49: 9
# filters_layer_50: 48
# kernel_size_layer_50: 5
# filters_layer_51: 112
# kernel_size_layer_38: 13
# filters_layer_39: 48
# kernel_size_layer_39: 7
# filters_layer_40: 64
# kernel_size_layer_40: 11
# filters_layer_41: 48
# kernel_size_layer_41: 9
# filters_layer_42: 96
# kernel_size_layer_42: 11
# filters_layer_43: 128
# kernel_size_layer_43: 15
# filters_layer_44: 128
# kernel_size_layer_44: 9
# filters_layer_45: 96
# kernel_size_layer_45: 13
# filters_layer_46: 48
# kernel_size_layer_46: 9
# filters_layer_47: 64
# kernel_size_layer_47: 5
# filters_layer_48: 112
# kernel_size_layer_48: 11
# filters_layer_49: 64
# kernel_size_layer_49: 5
# filters_layer_50: 48
# kernel_size_layer_50: 7
# filters_layer_51: 96
# kernel_size_layer_51: 5
# filters_layer_52: 64
# kernel_size_layer_52: 3
# filters_layer_53: 128
# kernel_size_layer_53: 15
# filters_layer_54: 16
# kernel_size_layer_54: 7
# filters_layer_55: 80
# kernel_size_layer_55: 3
# filters_layer_56: 64
# kernel_size_layer_56: 11
# filters_layer_57: 32
# kernel_size_layer_57: 9
# filters_layer_58: 96
# kernel_size_layer_58: 9
# filters_layer_59: 32
# kernel_size_layer_59: 7
# filters_layer_60: 128
# kernel_size_layer_60: 11
# filters_layer_61: 112
# kernel_size_layer_61: 7
# Score: 0.06529945135116577
#
# Trial 070 summary
# Hyperparameters:
# activation: relu
# num_hidden_layers: 7
# filters_layer_0: 80
# kernel_size_layer_0: 11
# optimizer: adam
# learning_rate: 0.0014268592025296091
# filters_layer_1: 32
# kernel_size_layer_1: 3
# filters_layer_2: 64
# kernel_size_layer_2: 9
# filters_layer_3: 32
# kernel_size_layer_3: 3
# filters_layer_4: 112
# kernel_size_layer_4: 7
# filters_layer_5: 32
# kernel_size_layer_5: 7
# filters_layer_6: 64
# kernel_size_layer_6: 11
# filters_layer_7: 32
# kernel_size_layer_7: 9
# filters_layer_8: 32
# kernel_size_layer_8: 3
# filters_layer_9: 80
# kernel_size_layer_9: 3
# filters_layer_10: 80
# kernel_size_layer_10: 3
# filters_layer_11: 48
# kernel_size_layer_11: 15
# filters_layer_12: 48
# kernel_size_layer_12: 9
# filters_layer_13: 64
# kernel_size_layer_13: 11
# filters_layer_14: 112
# kernel_size_layer_14: 15
# filters_layer_15: 32
# kernel_size_layer_15: 11
# filters_layer_16: 128
# kernel_size_layer_16: 15
# filters_layer_17: 16
# kernel_size_layer_17: 15
# filters_layer_18: 96
# kernel_size_layer_18: 13
# filters_layer_19: 96
# kernel_size_layer_19: 9
# filters_layer_20: 128
# kernel_size_layer_20: 7
# filters_layer_21: 64
# kernel_size_layer_21: 7
# filters_layer_22: 48
# kernel_size_layer_22: 15
# filters_layer_23: 32
# kernel_size_layer_23: 13
# filters_layer_24: 80
# kernel_size_layer_24: 3
# filters_layer_25: 16
# kernel_size_layer_25: 3
# filters_layer_26: 16
# kernel_size_layer_26: 3
# filters_layer_27: 16
# kernel_size_layer_27: 9
# filters_layer_28: 80
# kernel_size_layer_28: 9
# filters_layer_29: 32
# kernel_size_layer_29: 11
# filters_layer_30: 128
# kernel_size_layer_30: 5
# filters_layer_31: 64
# filters_layer_25: 96
# kernel_size_layer_25: 15
# filters_layer_26: 48
# kernel_size_layer_26: 9
# filters_layer_27: 32
# kernel_size_layer_27: 7
# filters_layer_28: 112
# kernel_size_layer_28: 15
# filters_layer_29: 32
# kernel_size_layer_29: 15
# filters_layer_30: 80
# kernel_size_layer_30: 7
# filters_layer_31: 128
# kernel_size_layer_31: 3
# filters_layer_32: 32
# kernel_size_layer_32: 7
# filters_layer_33: 64
# kernel_size_layer_33: 11
# filters_layer_34: 128
# kernel_size_layer_34: 15
# filters_layer_35: 112
# kernel_size_layer_35: 7
# filters_layer_36: 48
# kernel_size_layer_36: 13
# filters_layer_37: 112
# kernel_size_layer_37: 5
# filters_layer_38: 112
# kernel_size_layer_38: 3
# filters_layer_39: 96
# kernel_size_layer_39: 7
# filters_layer_40: 80
# kernel_size_layer_40: 3
# filters_layer_41: 48
# kernel_size_layer_41: 13
# filters_layer_42: 32
# kernel_size_layer_42: 13
# filters_layer_43: 80
# kernel_size_layer_43: 13
# filters_layer_44: 32
# kernel_size_layer_44: 7
# filters_layer_45: 64
# kernel_size_layer_45: 7
# filters_layer_46: 32
# kernel_size_layer_46: 3
# Score: 0.06583601236343384
#
# Trial 029 summary
# Hyperparameters:
# activation: relu
# num_hidden_layers: 1
# filters_layer_0: 48
# kernel_size_layer_0: 11
# optimizer: rmsprop
# learning_rate: 0.00011227880815579792
# filters_layer_1: 48
# kernel_size_layer_1: 13
# filters_layer_2: 32
# kernel_size_layer_2: 11
# filters_layer_3: 128
# kernel_size_layer_3: 3
# filters_layer_4: 96
# kernel_size_layer_4: 7
# filters_layer_5: 80
# kernel_size_layer_5: 3
# filters_layer_6: 48
# kernel_size_layer_6: 13
# filters_layer_7: 112
# kernel_size_layer_7: 5
# filters_layer_8: 112
# kernel_size_layer_8: 5
# filters_layer_9: 112
# kernel_size_layer_9: 5
# filters_layer_10: 128
# kernel_size_layer_10: 5
# filters_layer_11: 16
# kernel_size_layer_11: 11
# filters_layer_12: 128
# kernel_size_layer_12: 5
# filters_layer_13: 80
# kernel_size_layer_13: 9
# filters_layer_14: 48
# kernel_size_layer_14: 3
# filters_layer_15: 128
# kernel_size_layer_15: 9
# filters_layer_16: 128
# kernel_size_layer_16: 7
# filters_layer_17: 64
# kernel_size_layer_17: 11
# filters_layer_18: 96
# kernel_size_layer_18: 9
# filters_layer_19: 48
# kernel_size_layer_19: 3
# filters_layer_20: 64
# kernel_size_layer_20: 11
# filters_layer_21: 64
# kernel_size_layer_21: 5
# filters_layer_22: 80
# kernel_size_layer_22: 7
# filters_layer_23: 80
# kernel_size_layer_23: 3
# filters_layer_24: 96
# kernel_size_layer_24: 3
# filters_layer_25: 16
# kernel_size_layer_25: 5
# filters_layer_26: 128
# kernel_size_layer_26: 13
# filters_layer_27: 64
# kernel_size_layer_27: 7
# filters_layer_28: 96
# kernel_size_layer_28: 9
# filters_layer_29: 80
# kernel_size_layer_29: 13
# filters_layer_30: 96
# kernel_size_layer_30: 7
# filters_layer_31: 64
# kernel_size_layer_31: 13
# filters_layer_32: 48
# kernel_size_layer_32: 7
# filters_layer_33: 32
# kernel_size_layer_33: 11
# filters_layer_34: 128
# kernel_size_layer_34: 7
# filters_layer_35: 128
# kernel_size_layer_35: 9
# filters_layer_36: 80
# kernel_size_layer_36: 7
# filters_layer_37: 64
# kernel_size_layer_37: 11
# filters_layer_38: 48
# kernel_size_layer_38: 11
# filters_layer_39: 16
# kernel_size_layer_39: 7
# filters_layer_40: 128
# kernel_size_layer_40: 3
# filters_layer_41: 80
# kernel_size_layer_41: 5
# filters_layer_42: 32
# kernel_size_layer_42: 11
# filters_layer_43: 96
# kernel_size_layer_43: 11
# filters_layer_44: 32
# kernel_size_layer_44: 3
# filters_layer_45: 48
# kernel_size_layer_45: 13
# filters_layer_46: 80
# kernel_size_layer_46: 13
# filters_layer_47: 32
# kernel_size_layer_47: 15
# filters_layer_48: 16
# kernel_size_layer_48: 5
# filters_layer_49: 48
# kernel_size_layer_49: 15
# filters_layer_50: 96
# kernel_size_layer_50: 9
# filters_layer_51: 64
# kernel_size_layer_51: 5
# filters_layer_52: 64
# kernel_size_layer_52: 15
# filters_layer_53: 64
# kernel_size_layer_53: 9
# filters_layer_54: 112
# kernel_size_layer_54: 7
# filters_layer_55: 32
# kernel_size_layer_55: 11
# filters_layer_56: 64
# kernel_size_layer_56: 15
# filters_layer_57: 64
# kernel_size_layer_57: 13
# filters_layer_58: 32
# kernel_size_layer_58: 9
# filters_layer_59: 80
# kernel_size_layer_59: 15
# filters_layer_60: 80
# kernel_size_layer_60: 9
# filters_layer_61: 80
# kernel_size_layer_61: 13
# Score: 0.06681525707244873
#
# Trial 022 summary
# Hyperparameters:
# activation: relu
# num_hidden_layers: 18
# filters_layer_0: 128
# kernel_size_layer_0: 13
# optimizer: rmsprop
# learning_rate: 0.00016388795637466613
# filters_layer_1: 96
# kernel_size_layer_1: 5
# filters_layer_2: 64
# kernel_size_layer_2: 7
# filters_layer_3: 80
# kernel_size_layer_3: 5
# filters_layer_4: 64
# kernel_size_layer_4: 7
# filters_layer_5: 64
# kernel_size_layer_5: 3
# filters_layer_6: 32
# kernel_size_layer_6: 3
# filters_layer_7: 32
# kernel_size_layer_7: 3
# filters_layer_8: 16
# kernel_size_layer_8: 15
# filters_layer_9: 48
# kernel_size_layer_9: 9
# filters_layer_10: 112
# kernel_size_layer_10: 11
# filters_layer_11: 16
# kernel_size_layer_11: 13
# filters_layer_12: 112
# kernel_size_layer_12: 9
# filters_layer_13: 32
# kernel_size_layer_13: 15
# filters_layer_14: 16
# kernel_size_layer_14: 11
# filters_layer_15: 32
# kernel_size_layer_15: 5
# filters_layer_16: 128
# kernel_size_layer_16: 5
# filters_layer_17: 96
# kernel_size_layer_17: 5
# filters_layer_18: 112
# kernel_size_layer_18: 9
# filters_layer_19: 16
# kernel_size_layer_19: 5
# filters_layer_20: 80
# kernel_size_layer_20: 11
# filters_layer_21: 128
# kernel_size_layer_21: 13
# filters_layer_22: 112
# kernel_size_layer_22: 11
# filters_layer_23: 16
# kernel_size_layer_23: 9
# filters_layer_24: 112
# kernel_size_layer_24: 15
# filters_layer_25: 48
# kernel_size_layer_25: 11
# filters_layer_26: 32
# kernel_size_layer_26: 15
# filters_layer_27: 16
# kernel_size_layer_27: 3
# filters_layer_28: 80
# kernel_size_layer_28: 7
# filters_layer_29: 64
# kernel_size_layer_29: 15
# filters_layer_30: 16
# kernel_size_layer_30: 15
# filters_layer_31: 80
# kernel_size_layer_31: 9
# filters_layer_32: 16
# kernel_size_layer_32: 7
# filters_layer_33: 48
# kernel_size_layer_33: 13
# filters_layer_34: 112
# kernel_size_layer_34: 15
# filters_layer_35: 32
# kernel_size_layer_35: 5
# filters_layer_36: 48
# kernel_size_layer_36: 5
# filters_layer_37: 16
# kernel_size_layer_37: 5
# filters_layer_38: 96
# kernel_size_layer_38: 5
# filters_layer_39: 32
# kernel_size_layer_39: 7
# filters_layer_40: 96
# kernel_size_layer_40: 5
# filters_layer_41: 128
# kernel_size_layer_41: 13
# filters_layer_42: 16
# kernel_size_layer_42: 15
# filters_layer_43: 112
# kernel_size_layer_43: 3
# filters_layer_44: 32
# kernel_size_layer_44: 13
# filters_layer_45: 16
# kernel_size_layer_45: 7
# filters_layer_46: 80
# kernel_size_layer_46: 3
# Score: 0.06750085949897766

# %%
# Récupérer les essais
trials = tuner.oracle.get_best_trials(num_trials=100)

# Extraire les détails de chaque essai et les convertir en un DataFrame Pandas
df = pd.DataFrame([t.hyperparameters.values for t in trials])
df['score'] = [t.score for t in trials]

# Trier par score pour voir l'évolution
df = df.sort_values('score')

# Vous pouvez maintenant visualiser les données avec des graphiques, par exemple:
df['score'].plot()
print(df[['activation','num_hidden_layers','optimizer','score','filters_layer_0','kernel_size_layer_0','learning_rate']].head(20))
# Out:
#    activation  num_hidden_layers optimizer     score  filters_layer_0  \
# 0        relu                 11      adam  0.061565               48
# 1        relu                  3      adam  0.062991               48
# 2        relu                 11      adam  0.063081               48
# 3         elu                 29      adam  0.063333              112
# 4        relu                  2   rmsprop  0.064896               96
# 5        relu                  7   rmsprop  0.065299               96
# 6        relu                  7      adam  0.065758               80
# 7        relu                 11      adam  0.065836               80
# 8        relu                  1   rmsprop  0.066815               48
# 9        relu                 18   rmsprop  0.067501              128
# 10       relu                 18      adam  0.067693               16
# 11       relu                  1   rmsprop  0.067808               96
# 12       relu                  4   rmsprop  0.068094               48
# 13       relu                  4      adam  0.068268               32
# 14       relu                  4      adam  0.068393              112
# 15       relu                  4   rmsprop  0.068790              128
# 16       relu                  7   rmsprop  0.069180              128
# 17       relu                  2   rmsprop  0.069468               64
# 18       relu                  1      adam  0.069682               32
# 19        elu                 29      adam  0.069870              112
#
#     kernel_size_layer_0  learning_rate
# 0                    13       0.000111
# 1                    13       0.002334
# 2                    15       0.000329
# 3                     3       0.000485
# 4                     9       0.000141
# 5                     7       0.000564
# 6                    11       0.001427
# 7                     9       0.000867
# 8                    11       0.000112
# 9                    13       0.000164
# 10                    3       0.000207
# 11                    9       0.005682
# 12                   15       0.001629
# 13                    5       0.003220
# 14                   11       0.002662
# 15                    9       0.000101
# 16                    9       0.001344
# 17                    9       0.004444
# 18                    9       0.001136
# 19                    3       0.000174
